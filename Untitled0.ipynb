# %% [markdown]
# <a href="https://colab.research.google.com/github/jhenningsen/Equity_Analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.4.71b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting numba==0.61.2 (from pandas_ta)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.2 (from pandas_ta)
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from pandas_ta) (4.67.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->pandas_ta)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas_ta) (1.17.0)
# Downloading pandas_ta-0.4.71b0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 12.0 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 69.6 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 77.7 MB/s eta 0:00:00
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 41.0 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 13.4 MB/s eta 0:00:00
# Installing collected packages: numpy, llvmlite, pandas, numba, pandas_ta
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.0 which is incompatible.
# Successfully installed llvmlite-0.44.0 numba-0.61.2 numpy-2.2.6 pandas-3.0.0 pandas_ta-0.4.71b0

# %%
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import numpy as np

# 1. Setup Ranges
SMA_RANGE = range(3, 21)  # 3 to 20 inclusive
BB_PERIODS = [10, 20, 30]
SYMBOLS = [
    "TSLA", "SPY", "QQQ", "NVDA", "META", "MSTR", "COIN", "GLD", "AMD", "SLV",
    "PLTR", "MSFT", "ORCL", "IWM", "AAPL", "AVGO", "AMZN", "UNH", "NFLX", "MU",
    "GOOGL", "TSM", "LULU", "CRWV", "GOOG", "IBIT", "JPM", "HOOD", "GDX", "ADBE",
    "NOW", "APP", "GS", "WOLF", "BABA", "IREN", "COST", "INTC", "LLY", "CRCL",
    "CVNA", "SNDK", "OKLO", "SMH", "BA", "BMNR", "ASTS", "NBIS", "SOFI", "BE"
]

# 2. Optimized Data Cache
print("Fetching fresh data...")
data_cache = {}
for s in SYMBOLS:
    df = yf.download(s, period="5y", interval="1d", progress=False, auto_adjust=True)
    if not df.empty:
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(0)
        data_cache[s] = df

# 3. Execution
results = []

print("Analyzing Parameter Surface...")
for sma_val in SMA_RANGE:
    for bb_val in BB_PERIODS:
        trade_data = []

        for symbol, df_orig in data_cache.items():
            df = df_orig.copy()

            # Indicators
            df['SMA'] = ta.sma(df['Close'], length=sma_val)
            bb = ta.bbands(df['Close'], length=bb_val, std=2)
            if bb is None: continue

            bbm_col = [c for c in bb.columns if c.startswith('BBM')][0]
            df['Mid_B'] = bb[bbm_col]

            # Logic: Cross above SMA AND Below BB Midpoint
            df['Prev_Close'] = df['Close'].shift(1)
            df['Prev_SMA'] = df['SMA'].shift(1)

            cond_cross = (df['Close'] > df['SMA']) & (df['Prev_Close'] <= df['Prev_SMA'])
            cond_value = df['Close'] < df['Mid_B']
            df['Signal'] = np.where(cond_cross & cond_value, 1, 0)

            # Calculate Multi-Window Forward Returns
            df['Ret_3D'] = df['Close'].pct_change(3).shift(-3)
            df['Ret_5D'] = df['Close'].pct_change(5).shift(-5)
            df['Ret_10D'] = df['Close'].pct_change(10).shift(-10)

            # Filter for trade outcomes
            trades = df[df['Signal'] == 1][['Ret_3D', 'Ret_5D', 'Ret_10D']]
            trade_data.append(trades)

        # Aggregate all trades for this parameter set
        all_trades = pd.concat(trade_data)
        if not all_trades.empty:
            results.append({
                "SMA": sma_val,
                "BB": bb_val,
                "Total_Trades": len(all_trades),
                # ADD THESE THREE LINES:
                "Wins_3D": (all_trades['Ret_3D'] > 0).sum(),
                "Wins_5D": (all_trades['Ret_5D'] > 0).sum(),
                "Wins_10D": (all_trades['Ret_10D'] > 0).sum(),

                "Avg_3D": all_trades['Ret_3D'].mean(),
                "Avg_5D": all_trades['Ret_5D'].mean(),
                "Avg_10D": all_trades['Ret_10D'].mean()
            })

# 4. Visualization
master_results = pd.DataFrame(results)

# Pivot for the 5-day return as the primary benchmark
pivot_5d = master_results.pivot(index="SMA", columns="BB", values="Avg_5D")

print("\n--- Heatmap: Average 5-Day Return by Parameters ---")
display(pivot_5d.style.background_gradient(cmap='RdYlGn', axis=None).format("{:.2%}"))

# Pivot for the 10-day return as the primary benchmark
pivot_10d = master_results.pivot(index="SMA", columns="BB", values="Avg_10D")

print("\n--- Heatmap: Average 10-Day Return by Parameters ---")
display(pivot_10d.style.background_gradient(cmap='RdYlGn', axis=None).format("{:.2%}"))

print("\n--- Summary: Top 5 Parameter Sets (by 10-Day Return) ---")
display(master_results.sort_values('Avg_10D', ascending=False).head(5))
# Out:
# Fetching fresh data...
# Analyzing Parameter Surface...
#
# --- Heatmap: Average 5-Day Return by Parameters ---
# <style type="text/css">
# #T_72d10_row0_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_72d10_row0_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_72d10_row0_col2, #T_72d10_row5_col2, #T_72d10_row14_col1 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_72d10_row1_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_72d10_row1_col1, #T_72d10_row4_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_72d10_row1_col2 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_72d10_row2_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_72d10_row2_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_72d10_row2_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_72d10_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_72d10_row3_col1 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_72d10_row3_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_72d10_row4_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_72d10_row4_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_72d10_row5_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_72d10_row5_col1 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_72d10_row6_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_72d10_row6_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_72d10_row6_col2 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_72d10_row7_col0, #T_72d10_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_72d10_row7_col1, #T_72d10_row13_col0 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_72d10_row7_col2, #T_72d10_row14_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_72d10_row8_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_72d10_row8_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_72d10_row8_col2, #T_72d10_row10_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_72d10_row9_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_72d10_row9_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_72d10_row9_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_72d10_row10_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_72d10_row10_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_72d10_row11_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_72d10_row11_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_72d10_row11_col2 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_72d10_row12_col0, #T_72d10_row17_col2 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_72d10_row12_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_72d10_row12_col2 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_72d10_row13_col1 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_72d10_row13_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_72d10_row14_col0 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_72d10_row15_col0 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_72d10_row15_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_72d10_row15_col2 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_72d10_row16_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_72d10_row16_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_72d10_row16_col2 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_72d10_row17_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72d10" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB</th>
#       <th id="T_72d10_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_72d10_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_72d10_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72d10_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_72d10_row0_col0" class="data row0 col0" >0.85%</td>
#       <td id="T_72d10_row0_col1" class="data row0 col1" >0.37%</td>
#       <td id="T_72d10_row0_col2" class="data row0 col2" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_72d10_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_72d10_row1_col0" class="data row1 col0" >0.88%</td>
#       <td id="T_72d10_row1_col1" class="data row1 col1" >0.22%</td>
#       <td id="T_72d10_row1_col2" class="data row1 col2" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_72d10_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_72d10_row2_col0" class="data row2 col0" >-0.15%</td>
#       <td id="T_72d10_row2_col1" class="data row2 col1" >0.11%</td>
#       <td id="T_72d10_row2_col2" class="data row2 col2" >0.14%</td>
#     </tr>
#     <tr>
#       <th id="T_72d10_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T
</td>
#     </tr>
#     <tr>
#       <th id="T_2551a_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_2551a_row12_col0" class="data row12 col0" >1.93%</td>
#       <td id="T_2551a_row12_col1" class="data row12 col1" >1.07%</td>
#       <td id="T_2551a_row12_col2" class="data row12 col2" >1.11%</td>
#     </tr>
#     <tr>
#       <th id="T_2551a_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_2551a_row13_col0" class="data row13 col0" >1.44%</td>
#       <td id="T_2551a_row13_col1" class="data row1
# --- Summary: Top 5 Parameter Sets (by 10-Day Return) ---
#     SMA  BB  Total_Trades  Wins_3D  Wins_5D  Wins_10D    Avg_3D    Avg_5D  \
# 32   14  10           395      209      215       228  0.008650  0.010003
# 35   15  10           421      209      224       230  0.003832  0.004569
# 26   12  10           306      154      170       181  0.004161  0.009644
# 29   13  10           370      188      196       208  0.004476  0.007831
# 25   11  30          1843     1018      995      1040  0.004561  0.004659
#
#      Avg_10D
# 32  0.021670
# 35  0.019257
# 26  0.017480
# 29  0.014912
# 25  0.014690

# %%
# Create the CSV string
csv_output = master_results.to_csv(index=False)

# Print it in a way that is easy to copy
print("--- COPY THE BLOCK BELOW AND PASTE IT TO GEMINI ---")
print(csv_output)
# Out:
# --- COPY THE BLOCK BELOW AND PASTE IT TO GEMINI ---
# SMA,BB,Total_Trades,Wins_3D,Wins_5D,Wins_10D,Avg_3D,Avg_5D,Avg_10D
# 3,10,4293,2187,2151,2266,0.00474326990046934,0.008472224814366349,0.010594842975858314
# 3,20,4402,2334,2296,2358,0.004231876824114142,0.0036923317238501847,0.010346094434843004
# 3,30,4344,2272,2250,2318,0.003163398374762604,0.0028413918520247944,0.010422086473294474
# 4,10,3314,1659,1658,1718,0.003728802646695674,0.008827162240857842,0.009288423652960478
# 4,20,3589,1882,1850,1887,0.00276777901822925,0.002205220029797137,0.008239410517542777
# 4,30,3563,1850,1836,1879,0.0019503166145836638,0.0019448669255940952,0.008466790003795995
# 5,10,2604,1272,1263,1322,-0.0008843420704991771,-0.0014752960691580001,0.004419790336313832
# 5,20,3063,1592,1550,1592,0.0018953446744061693,0.001066028302408307,0.006731695903910631
# 5,30,3071,1584,1567,1602,0.0012093180782228995,0.0014098243739629596,0.007675200017162987
# 6,10,2029,975,983,1026,-0.002419471268414259,-0.003911083902188763,0.0033993703585625803
# 6,20,2679,1397,1378,1408,0.001970204046793874,0.0006749338597028074,0.008649599740646531
# 6,30,2696,1414,1398,1427,0.0021640380476420236,0.0019728925106632343,0.009935994526515637
# 7,10,1584,758,778,810,-0.002501299695200968,-0.0028313972708241945,0.006441813471219545
# 7,20,2411,1259,1251,1284,0.0010972533128267253,0.0008255838369433348,0.010104359336489902
# 7,30,2460,1294,1283,1319,0.0017745393752080134,0.0021827624715883387,0.01132738157951909
# 8,10,1055,506,520,550,-0.0016264085591112518,-0.003341067484038006,0.009159347590065524
# 8,20,2168,1143,1137,1167,0.0018500709838460108,0.0008001293508480262,0.011229872034563205
# 8,30,2260,1212,1195,1224,0.0028677165287893,0.0028393229471750823,0.012813082904105226
# 9,10,545,263,273,287,-0.0016266262674993557,-0.001028310509508234,0.007834383417261883
