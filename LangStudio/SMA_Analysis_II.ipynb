# %% [markdown]
# <a href="https://colab.research.google.com/github/jhenningsen/Equity_Analysis/blob/main/LangStudio/SMA_Analysis_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.4.71b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting numba==0.61.2 (from pandas_ta)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.2 (from pandas_ta)
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from pandas_ta) (4.67.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->pandas_ta)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas_ta) (1.17.0)
# Downloading pandas_ta-0.4.71b0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 12.0 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 69.6 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 77.7 MB/s eta 0:00:00
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 41.0 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 13.4 MB/s eta 0:00:00
# Installing collected packages: numpy, llvmlite, pandas, numba, pandas_ta
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.0 which is incompatible.
# Successfully installed llvmlite-0.44.0 numba-0.61.2 numpy-2.2.6 pandas-3.0.0 pandas_ta-0.4.71b0

# %%
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import numpy as np

# 1. Setup Ranges
SMA_RANGE = range(3, 21)  # 3 to 20 inclusive
BB_PERIODS = [10, 20, 30]
SYMBOLS = ["TSLA", "NVDA", "AAPL", "MSFT", "AMD", "META", "GOOGL", "AMZN", "NFLX"]

# 2. Optimized Data Cache
print("Fetching fresh data...")
data_cache = {}
for s in SYMBOLS:
    df = yf.download(s, period="5y", interval="1d", progress=False, auto_adjust=True)
    if not df.empty:
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(0)
        data_cache[s] = df

# 3. Execution
results = []

print("Analyzing Parameter Surface...")
for sma_val in SMA_RANGE:
    for bb_val in BB_PERIODS:
        trade_data = []

        for symbol, df_orig in data_cache.items():
            df = df_orig.copy()

            # Indicators
            df['SMA'] = ta.sma(df['Close'], length=sma_val)
            bb = ta.bbands(df['Close'], length=bb_val, std=2)
            if bb is None: continue

            bbm_col = [c for c in bb.columns if c.startswith('BBM')][0]
            df['Mid_B'] = bb[bbm_col]

            # Logic: Cross above SMA AND Below BB Midpoint
            df['Prev_Close'] = df['Close'].shift(1)
            df['Prev_SMA'] = df['SMA'].shift(1)

            cond_cross = (df['Close'] > df['SMA']) & (df['Prev_Close'] <= df['Prev_SMA'])
            cond_value = df['Close'] < df['Mid_B']
            df['Signal'] = np.where(cond_cross & cond_value, 1, 0)

            # Calculate Multi-Window Forward Returns
            df['Ret_3D'] = df['Close'].pct_change(3).shift(-3)
            df['Ret_5D'] = df['Close'].pct_change(5).shift(-5)
            df['Ret_10D'] = df['Close'].pct_change(10).shift(-10)

            # Filter for trade outcomes
            trades = df[df['Signal'] == 1][['Ret_3D', 'Ret_5D', 'Ret_10D']]
            trade_data.append(trades)

        # Aggregate all trades for this parameter set
        all_trades = pd.concat(trade_data)
        if not all_trades.empty:
            results.append({
                "SMA": sma_val,
                "BB": bb_val,
                "Total_Trades": len(all_trades),
                # ADD THESE THREE LINES:
                "Wins_3D": (all_trades['Ret_3D'] > 0).sum(),
                "Wins_5D": (all_trades['Ret_5D'] > 0).sum(),
                "Wins_10D": (all_trades['Ret_10D'] > 0).sum(),

                "Avg_3D": all_trades['Ret_3D'].mean(),
                "Avg_5D": all_trades['Ret_5D'].mean(),
                "Avg_10D": all_trades['Ret_10D'].mean()
            })

# 4. Visualization
master_results = pd.DataFrame(results)

# Pivot for the 5-day return as the primary benchmark
pivot_5d = master_results.pivot(index="SMA", columns="BB", values="Avg_5D")

print("\n--- Heatmap: Average 5-Day Return by Parameters ---")
display(pivot_5d.style.background_gradient(cmap='RdYlGn', axis=None).format("{:.2%}"))

# Pivot for the 10-day return as the primary benchmark
pivot_10d = master_results.pivot(index="SMA", columns="BB", values="Avg_10D")

print("\n--- Heatmap: Average 10-Day Return by Parameters ---")
display(pivot_10d.style.background_gradient(cmap='RdYlGn', axis=None).format("{:.2%}"))

print("\n--- Summary: Top 5 Parameter Sets (by 10-Day Return) ---")
display(master_results.sort_values('Avg_10D', ascending=False).head(5))
# Out:
# Fetching fresh data...
# Analyzing Parameter Surface...
#
# --- Heatmap: Average 5-Day Return by Parameters ---
# <style type="text/css">
# #T_0765e_row0_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_0765e_row0_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_0765e_row0_col2, #T_0765e_row6_col2 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_0765e_row1_col0 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_0765e_row1_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_0765e_row1_col2 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_0765e_row2_col0 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_0765e_row2_col1 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_0765e_row2_col2 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_0765e_row3_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_0765e_row3_col1 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_0765e_row3_col2 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_0765e_row4_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_0765e_row4_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_0765e_row4_col2 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_0765e_row5_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_0765e_row5_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_0765e_row5_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_0765e_row6_col0 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_0765e_row6_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_0765e_row7_col0, #T_0765e_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_0765e_row7_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_0765e_row7_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_0765e_row8_col0 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_0765e_row8_col1, #T_0765e_row12_col0, #T_0765e_row14_col1 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_0765e_row8_col2 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_0765e_row9_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0765e_row9_col1 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_0765e_row9_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_0765e_row10_col0 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_0765e_row10_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_0765e_row10_col2 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_0765e_row11_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_0765e_row11_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_0765e_row11_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_0765e_row12_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_0765e_row12_col2 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_0765e_row13_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_0765e_row13_col1 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_0765e_row13_col2 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_0765e_row14_col0 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_0765e_row14_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_0765e_row15_col0 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_0765e_row15_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_0765e_row15_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_0765e_row16_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_0765e_row16_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0765e_row16_col2 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_0765e_row17_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_0765e_row17_col2 {
#   background-color: #ddf191;
#   color: #000000;
# }
# </style>
# <table id="T_0765e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB</th>
#       <th id="T_0765e_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_0765e_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_0765e_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0765e_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_0765e_row0_col0" class="data row0 col0" >0.02%</td>
#       <td id="T_0765e_row0_col1" class="data row0 col1" >0.21%</td>
#       <td id="T_0765e_row0_col2" class="data row0 col2" >0.20%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_0765e_row1_col0" class="data row1 col0" >-0.38%</td>
#       <td id="T_0765e_row1_col1" class="data row1 col1" >-0.08%</td>
#       <td id="T_0765e_row1_col2" class="data row1 col2" >-0.03%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_0765e_row2_col0" class="data row2 col0" >-0.48%</td>
#       <td id="T_0765e_row2_col1" class="data row2 col1" >-0.14%</td>
#       <td id="T_0765e_row2_col2" class="data row2 col2" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_0765e_row3_col0" class="data row3 col0" >-0.77%</td>
#       <td id="T_0765e_row3_col1" class="data row3 col1" >-0.28%</td>
#       <td id="T_0765e_row3_col2" class="data row3 col2" >0.09%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_0765e_row4_col0" class="data row4 col0" >-1.09%</td>
#       <td id="T_0765e_row4_col1" class="data row4 col1" >-0.52%</td>
#       <td id="T_0765e_row4_col2" class="data row4 col2" >-0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_0765e_row5_col0" class="data row5 col0" >-0.99%</td>
#       <td id="T_0765e_row5_col1" class="data row5 col1" >-0.36%</td>
#       <td id="T_0765e_row5_col2" class="data row5 col2" >0.09%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_0765e_row6_col0" class="data row6 col0" >-0.48%</td>
#       <td id="T_0765e_row6_col1" class="data row6 col1" >-0.14%</td>
#       <td id="T_0765e_row6_col2" class="data row6 col2" >0.20%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_0765e_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_0765e_row7_col1" class="data row7 col1" >-0.07%</td>
#       <td id="T_0765e_row7_col2" class="data row7 col2" >0.10%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_0765e_row8_col0" class="data row8 col0" >0.48%</td>
#       <td id="T_0765e_row8_col1" class="data row8 col1" >0.14%</td>
#       <td id="T_0765e_row8_col2" class="data row8 col2" >0.31%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_0765e_row9_col0" class="data row9 col0" >0.86%</td>
#       <td id="T_0765e_row9_col1" class="data row9 col1" >0.18%</td>
#       <td id="T_0765e_row9_col2" class="data row9 col2" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_0765e_row10_col0" class="data row10 col0" >0.62%</td>
#       <td id="T_0765e_row10_col1" class="data row10 col1" >0.25%</td>
#       <td id="T_0765e_row10_col2" class="data row10 col2" >0.25%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_0765e_row11_col0" class="data row11 col0" >0.74%</td>
#       <td id="T_0765e_row11_col1" class="data row11 col1" >0.43%</td>
#       <td id="T_0765e_row11_col2" class="data row11 col2" >0.06%</td>
#     </tr>
#     <tr>
#       <th id="T_0765e_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_0765e_row12_col0" class="data row12 col0" >0.13%</td>
#       <td id="T_0765e_row12_col1" class="d
# --- Heatmap: Average 10-Day Return by Parameters ---
# <style type="text/css">
# #T_512bc_row0_col0 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_512bc_row0_col1 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_512bc_row0_col2, #T_512bc_row17_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_512bc_row1_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_512bc_row1_col1, #T_512bc_row15_col1 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_512bc_row1_col2, #T_512bc_row2_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_512bc_row2_col0 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_512bc_row2_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_512bc_row3_col0, #T_512bc_row4_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_512bc_row3_col1 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_512bc_row3_col2, #T_512bc_row4_col2, #T_512bc_row14_col1, #T_512bc_row16_col2 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_512bc_row4_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_512bc_row5_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_512bc_row5_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_512bc_row5_col2, #T_512bc_row9_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_512bc_row6_col0 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_512bc_row6_col1, #T_512bc_row7_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_512bc_row6_col2 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_512bc_row7_col0, #T_512bc_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_512bc_row7_col2, #T_512bc_row10_col2 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_512bc_row8_col0 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_512bc_row8_col1, #T_512bc_row12_col2 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_512bc_row8_col2, #T_512bc_row9_col2, #T_512bc_row10_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_512bc_row9_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_512bc_row10_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_512bc_row11_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_512bc_row11_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_512bc_row11_col2 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_512bc_row12_col0 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_512bc_row12_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_512bc_row13_col0 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_512bc_row13_col1 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_512bc_row13_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_512bc_row14_col0 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_512bc_row14_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_512bc_row15_col0 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_512bc_row15_col2 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_512bc_row16_col0 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_512bc_row16_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_512bc_row17_col0 {
#   background-color: #fec877;
#   color: #000000;
# }
# </style>
# <table id="T_512bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB</th>
#       <th id="T_512bc_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_512bc_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_512bc_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_512bc_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_512bc_row0_col0" class="data row0 col0" >0.64%</td>
#       <td id="T_512bc_row0_col1" class="data row0 col1" >0.83%</td>
#       <td id="T_512bc_row0_col2" class="data row0 col2" >0.85%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_512bc_row1_col0" class="data row1 col0" >0.17%</td>
#       <td id="T_512bc_row1_col1" class="data row1 col1" >0.50%</td>
#       <td id="T_512bc_row1_col2" class="data row1 col2" >0.51%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_512bc_row2_col0" class="data row2 col0" >0.02%</td>
#       <td id="T_512bc_row2_col1" class="data row2 col1" >0.37%</td>
#       <td id="T_512bc_row2_col2" class="data row2 col2" >0.51%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_512bc_row3_col0" class="data row3 col0" >-0.22%</td>
#       <td id="T_512bc_row3_col1" class="data row3 col1" >0.32%</td>
#       <td id="T_512bc_row3_col2" class="data row3 col2" >0.70%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_512bc_row4_col0" class="data row4 col0" >-0.22%</td>
#       <td id="T_512bc_row4_col1" class="data row4 col1" >0.42%</td>
#       <td id="T_512bc_row4_col2" class="data row4 col2" >0.70%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_512bc_row5_col0" class="data row5 col0" >-0.20%</td>
#       <td id="T_512bc_row5_col1" class="data row5 col1" >0.46%</td>
#       <td id="T_512bc_row5_col2" class="data row5 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_512bc_row6_col0" class="data row6 col0" >0.43%</td>
#       <td id="T_512bc_row6_col1" class="data row6 col1" >0.79%</td>
#       <td id="T_512bc_row6_col2" class="data row6 col2" >1.09%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_512bc_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_512bc_row7_col1" class="data row7 col1" >0.79%</td>
#       <td id="T_512bc_row7_col2" class="data row7 col2" >0.97%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_512bc_row8_col0" class="data row8 col0" >1.92%</td>
#       <td id="T_512bc_row8_col1" class="data row8 col1" >0.88%</td>
#       <td id="T_512bc_row8_col2" class="data row8 col2" >1.06%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_512bc_row9_col0" class="data row9 col0" >3.24%</td>
#       <td id="T_512bc_row9_col1" class="data row9 col1" >0.91%</td>
#       <td id="T_512bc_row9_col2" class="data row9 col2" >1.04%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_512bc_row10_col0" class="data row10 col0" >1.75%</td>
#       <td id="T_512bc_row10_col1" class="data row10 col1" >1.04%</td>
#       <td id="T_512bc_row10_col2" class="data row10 col2" >0.96%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_512bc_row11_col0" class="data row11 col0" >2.27%</td>
#       <td id="T_512bc_row11_col1" class="data row11 col1" >1.45%</td>
#       <td id="T_512bc_row11_col2" class="data row11 col2" >1.06%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_512bc_row12_col0" class="data row12 col0" >1.79%</td>
#       <td id="T_512bc_row12_col1" class="data row12 col1" >1.65%</td>
#       <td id="T_512bc_row12_col2" class="data row12 col2" >0.87%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_512bc_row13_col0" class="data row13 col0" >1.69%</td>
#       <td id="T_512bc_row13_col1" class="data row13 col1" >1.38%</td>
#       <td id="T_512bc_row13_col2" class="data row13 col2" >0.95%</td>
#     </tr>
#     <tr>
#       <th id="T_512bc_level0_row14" class="row_heading level0 row14" >17</th>
#       <td
# --- Summary: Top 5 Parameter Sets (by 10-Day Return) ---
#     SMA  BB  Total_Trades  Wins_3D  Wins_5D  Wins_10D    Avg_3D    Avg_5D  \
# 26   12  10            58       35       33        42  0.010968  0.008602
# 32   14  10            79       45       48        55  0.009717  0.007358
# 23   11  10            44       23       21        30  0.008303  0.004804
# 35   15  10            87       44       48        56  0.003409  0.001308
# 29   13  10            73       43       42        48  0.010536  0.006216
#
#      Avg_10D
# 26  0.032425
# 32  0.022664
# 23  0.019221
# 35  0.017934
# 29  0.017470
