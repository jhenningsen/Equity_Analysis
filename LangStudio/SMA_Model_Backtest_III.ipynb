# %% [markdown]
# <a href="https://colab.research.google.com/github/jhenningsen/Equity_Analysis/blob/main/LangStudio/SMA_Model_Backtest_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.4.71b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting numba==0.61.2 (from pandas_ta)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.2 (from pandas_ta)
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from pandas_ta) (4.67.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->pandas_ta)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting numpy>=2.2.6 (from pandas_ta)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.2->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas_ta) (1.17.0)
# Downloading pandas_ta-0.4.71b0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 10.9 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 48.1 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 65.4 MB/s eta 0:00:00
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 77.5 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 14.0 MB/s eta 0:00:00
# Installing collected packages: numpy, llvmlite, pandas, numba, pandas_ta
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.0 which is incompatible.
# Successfully installed llvmlite-0.44.0 numba-0.61.2 numpy-2.2.6 pandas-3.0.0 pandas_ta-0.4.71b0

# %%
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import numpy as np

# 1. Configuration
SMA_RANGE = range(3, 21)
BB_PERIODS = [10, 20, 30]
SYMBOLS = ["TSLA", "SPY", "QQQ", "NVDA", "META", "MSTR", "COIN", "GLD", "AMD", "SLV", "PLTR", "MSFT", "ORCL", "IWM", "AAPL", "AVGO", "AMZN", "UNH", "NFLX", "MU", "GOOGL", "TSM", "LULU", "CRWV", "GOOG", "IBIT", "JPM", "HOOD", "GDX", "ADBE", "NOW", "APP", "GS", "WOLF", "BABA", "IREN", "COST", "INTC", "LLY", "CRCL", "CVNA", "SNDK", "OKLO", "SMH", "BA", "BMNR", "ASTS", "NBIS", "SOFI", "BE"]

# 2. Optimized Data Cache
print("Fetching fresh data...")
data_cache = {}
for s in SYMBOLS:
    df = yf.download(s, period="5y", interval="1d", progress=False, auto_adjust=True)
    if not df.empty:
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(0)
        data_cache[s] = df

# 3. Generate Raw Trades with Technical Audit Columns
all_trades_list = []
print("Generating Technical Audit Logs...")

for sma_val in SMA_RANGE:
    for bb_val in BB_PERIODS:
        for symbol, df_orig in data_cache.items():
            df = df_orig.copy()

            # Indicators
            df['SMA_Value'] = ta.sma(df['Close'], length=sma_val)
            bb = ta.bbands(df['Close'], length=bb_val, std=2)
            if bb is None: continue

            bbm_col = [c for c in bb.columns if c.startswith('BBM')][0]
            df['BB_Midpoint'] = bb[bbm_col]

            # Logic: Cross above SMA AND Below BB Midpoint
            df['Prev_Close'] = df['Close'].shift(1)
            df['Prev_SMA'] = df['SMA_Value'].shift(1)

            cond_cross = (df['Close'] > df['SMA_Value']) & (df['Prev_Close'] <= df['Prev_SMA'])
            cond_value = df['Close'] < df['BB_Midpoint']

            # Filter and Label
            trades = df[cond_cross & cond_value].copy()
            if not trades.empty:
                # Forward Returns
                trades['Ret_3D'] = df['Close'].pct_change(3).shift(-3)
                trades['Ret_5D'] = df['Close'].pct_change(5).shift(-5)
                trades['Ret_10D'] = df['Close'].pct_change(10).shift(-10)

                # Metadata
                trades['Symbol'] = symbol
                trades['SMA_Param'] = sma_val
                trades['BB_Param'] = bb_val

                # Selecting Audit Columns
                audit_cols = [
                    'Symbol', 'SMA_Param', 'BB_Param',
                    'Close', 'SMA_Value', 'BB_Midpoint',
                    'Ret_3D', 'Ret_5D', 'Ret_10D'
                ]
                all_trades_list.append(trades[audit_cols])

master_trade_log = pd.concat(all_trades_list)
master_trade_log = master_trade_log.reset_index() # Keep the Date column
print(f"Done! {len(master_trade_log)} total trade instances recorded.")

# VIEW SPECIFIC SYMBOL DETAIL (Example: NVDA)
display(master_trade_log[master_trade_log['Symbol'] == 'NVDA'].head(20))
# Out:
# Fetching fresh data...
# Generating Technical Audit Logs...
# Done! 87094 total trade instances recorded.
# Price       Date Symbol  SMA_Param  BB_Param      Close  SMA_Value  \
# 255   2021-02-24   NVDA          3        10  14.458340  14.292057
# 256   2021-03-01   NVDA          3        10  13.802933  13.583052
# 257   2021-03-09   NVDA          3        10  12.489450  12.158914
# 258   2021-03-26   NVDA          3        10  12.807663  12.641324
# 259   2021-04-23   NVDA          3        10  15.227697  15.121376
# 260   2021-05-06   NVDA          3        10  14.487273  14.408715
# 261   2021-05-14   NVDA          3        10  14.207961  13.854748
# 262   2021-07-19   NVDA          3        10  18.737841  18.594081
# 263   2021-08-12   NVDA          3        10  19.860580  19.802378
# 264   2021-08-19   NVDA          3        10  19.753820  19.388636
# 265   2021-09-10   NVDA          3        10  22.431795  22.285430
# 266   2021-09-15   NVDA          3        10  22.295076  22.199273
# 267   2021-09-22   NVDA          3        10  21.895897  21.389275
# 268   2021-09-30   NVDA          3        10  20.673418  20.601566
# 269   2021-10-05   NVDA          3        10  20.408960  20.266589
# 270   2021-12-02   NVDA          3        10  32.063885  32.015644
# 271   2021-12-15   NVDA          3        10  30.400116  28.929627
# 272   2021-12-21   NVDA          3        10  29.018787  28.143814
# 273   2022-01-11   NVDA          3        10  27.763222  27.434858
# 274   2022-01-28   NVDA          3        10  22.795843  22.475131
#
# Price  BB_Midpoint    Ret_3D    Ret_5D   Ret_10D
# 255      14.754981 -0.045331 -0.116853 -0.139764
# 256      14.344884 -0.106309 -0.162443 -0.046666
# 257      13.015729  0.026817  0.061580  0.043969
# 258      12.934751  0.039644  0.089433  0.184571
# 259      15.384485  0.000753 -0.016754 -0.029675
# 260      14.953671 -0.014925 -0.059062  0.006163
# 261      14.286816 -0.012445  0.052570  0.140525
# 262      19.709346  0.043358  0.027383  0.051665
# 263      19.972931 -0.022457 -0.005375  0.108666
# 264      19.819174  0.100768  0.114658  0.131425
# 265      22.457443 -0.006095 -0.025714 -0.017662
# 266      22.361041 -0.054966 -0.017904 -0.081644
# 267      21.938011 -0.012807 -0.064901 -0.056561
# 268      21.391437 -0.012792  0.017330  0.049720
# 269      21.058723  0.018581  0.010758  0.089922
# 270      32.149755  0.009370 -0.050924 -0.116385
# 271      30.416479 -0.089957 -0.034768 -0.028661
# 272      29.188758  0.064316  0.031849 -0.050593
# 273      28.610082 -0.031456 -0.098860 -0.181364
# 274      23.822653  0.105166  0.064755  0.048555

# %%
# 1. Grouping by Symbol and Strategy Parameters
performance_summary = master_trade_log.groupby(['Symbol', 'SMA_Param', 'BB_Param']).agg(
    Trade_Count=('Ret_3D', 'count'),
    Wins_3D=('Ret_3D', lambda x: (x > 0).sum()),
    Wins_5D=('Ret_5D', lambda x: (x > 0).sum()),
    Wins_10D=('Ret_10D', lambda x: (x > 0).sum()),
    Avg_3D_Ret=('Ret_3D', 'mean'),
    Avg_5D_Ret=('Ret_5D', 'mean'),
    Avg_10D_Ret=('Ret_10D', 'mean')
).reset_index()

# 2. Calculate Win Rates
performance_summary['Win_Rate_3D'] = performance_summary['Wins_3D'] / performance_summary['Trade_Count']
performance_summary['Win_Rate_5D'] = performance_summary['Wins_5D'] / performance_summary['Trade_Count']
performance_summary['Win_Rate_10D'] = performance_summary['Wins_10D'] / performance_summary['Trade_Count']

# Define display columns for consistency
display_cols = [
    'Symbol', 'SMA_Param', 'BB_Param', 'Trade_Count',
    'Win_Rate_3D', 'Avg_3D_Ret',
    'Win_Rate_5D', 'Avg_5D_Ret',
    'Win_Rate_10D', 'Avg_10D_Ret'
]

# --- SECTION A: Best Parameter Set PER Symbol ---
# Sort by Symbol and Win Rate, then take the top 1 for each ticker
best_per_symbol = performance_summary.sort_values(
    ['Symbol', 'Win_Rate_10D', 'Avg_10D_Ret'],
    ascending=[True, False, False]
).groupby('Symbol').head(1)

print("--- [A] BEST PARAMETER COMBO PER SYMBOL (Top 25 by Win Rate) ---")
display(best_per_symbol[display_cols].sort_values('Win_Rate_10D', ascending=False).head(25).style.format({
    'Win_Rate_3D': '{:.1%}', 'Avg_3D_Ret': '{:.2%}',
    'Win_Rate_5D': '{:.1%}', 'Avg_5D_Ret': '{:.2%}',
    'Win_Rate_10D': '{:.1%}', 'Avg_10D_Ret': '{:.2%}'
}))
# Out:
# --- [A] BEST PARAMETER COMBO PER SYMBOL (Top 25 by Win Rate) ---
# <style type="text/css">
# </style>
# <table id="T_67e5e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67e5e_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_67e5e_level0_col1" class="col_heading level0 col1" >SMA_Param</th>
#       <th id="T_67e5e_level0_col2" class="col_heading level0 col2" >BB_Param</th>
#       <th id="T_67e5e_level0_col3" class="col_heading level0 col3" >Trade_Count</th>
#       <th id="T_67e5e_level0_col4" class="col_heading level0 col4" >Win_Rate_3D</th>
#       <th id="T_67e5e_level0_col5" class="col_heading level0 col5" >Avg_3D_Ret</th>
#       <th id="T_67e5e_level0_col6" class="col_heading level0 col6" >Win_Rate_5D</th>
#       <th id="T_67e5e_level0_col7" class="col_heading level0 col7" >Avg_5D_Ret</th>
#       <th id="T_67e5e_level0_col8" class="col_heading level0 col8" >Win_Rate_10D</th>
#       <th id="T_67e5e_level0_col9" class="col_heading level0 col9" >Avg_10D_Ret</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67e5e_level0_row0" class="row_heading level0 row0" >308</th>
#       <td id="T_67e5e_row0_col0" class="data row0 col0" >ASTS</td>
#       <td id="T_67e5e_row0_col1" class="data row0 col1" >19</td>
#       <td id="T_67e5e_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_67e5e_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_67e5e_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_67e5e_row0_col5" class="data row0 col5" >10.23%</td>
#       <td id="T_67e5e_row0_col6" class="data row0 col6" >100.0%</td>
#       <td id="T_67e5e_row0_col7" class="data row0 col7" >12.94%</td>
#       <td id="T_67e5e_row0_col8" class="data row0 col8" >100.0%</td>
#       <td id="T_67e5e_row0_col9" class="data row0 col9" >12.54%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row1" class="row_heading level0 row1" >188</th>
#       <td id="T_67e5e_row1_col0" class="data row1 col0" >AMZN</td>
#       <td id="T_67e5e_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_67e5e_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_67e5e_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_67e5e_row1_col4" class="data row1 col4" >37.5%</td>
#       <td id="T_67e5e_row1_col5" class="data row1 col5" >0.95%</td>
#       <td id="T_67e5e_row1_col6" class="data row1 col6" >87.5%</td>
#       <td id="T_67e5e_row1_col7" class="data row1 col7" >2.13%</td>
#       <td id="T_67e5e_row1_col8" class="data row1 col8" >100.0%</td>
#       <td id="T_67e5e_row1_col9" class="data row1 col9" >4.26%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row2" class="row_heading level0 row2" >764</th>
#       <td id="T_67e5e_row2_col0" class="data row2 col0" >CRWV</td>
#       <td id="T_67e5e_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_67e5e_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_67e5e_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_67e5e_row2_col4" class="data row2 col4" >100.0%</td>
#       <td id="T_67e5e_row2_col5" class="data row2 col5" >2.82%</td>
#       <td id="T_67e5e_row2_col6" class="data row2 col6" >100.0%</td>
#       <td id="T_67e5e_row2_col7" class="data row2 col7" >12.24%</td>
#       <td id="T_67e5e_row2_col8" class="data row2 col8" >100.0%</td>
#       <td id="T_67e5e_row2_col9" class="data row2 col9" >20.67%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row3" class="row_heading level0 row3" >807</th>
#       <td id="T_67e5e_row3_col0" class="data row3 col0" >CVNA</td>
#       <td id="T_67e5e_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_67e5e_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_67e5e_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_67e5e_row3_col4" class="data row3 col4" >100.0%</td>
#       <td id="T_67e5e_row3_col5" class="data row3 col5" >25.98%</td>
#       <td id="T_67e5e_row3_col6" class="data row3 col6" >83.3%</td>
#       <td id="T_67e5e_row3_col7" class="data row3 col7" >23.02%</td>
#       <td id="T_67e5e_row3_col8" class="data row3 col8" >100.0%</td>
#       <td id="T_67e5e_row3_col9" class="data row3 col9" >27.56%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row4" class="row_heading level0 row4" >387</th>
#       <td id="T_67e5e_row4_col0" class="data row4 col0" >BA</td>
#       <td id="T_67e5e_row4_col1" class="data row4 col1" >11</td>
#       <td id="T_67e5e_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_67e5e_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_67e5e_row4_col4" class="data row4 col4" >100.0%</td>
#       <td id="T_67e5e_row4_col5" class="data row4 col5" >0.24%</td>
#       <td id="T_67e5e_row4_col6" class="data row4 col6" >100.0%</td>
#       <td id="T_67e5e_row4_col7" class="data row4 col7" >9.43%</td>
#       <td id="T_67e5e_row4_col8" class="data row4 col8" >100.0%</td>
#       <td id="T_67e5e_row4_col9" class="data row4 col9" >8.31%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row5" class="row_heading level0 row5" >560</th>
#       <td id="T_67e5e_row5_col0" class="data row5 col0" >BMNR</td>
#       <td id="T_67e5e_row5_col1" class="data row5 col1" >17</td>
#       <td id="T_67e5e_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_67e5e_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_67e5e_row5_col4" class="data row5 col4" >100.0%</td>
#       <td id="T_67e5e_row5_col5" class="data row5 col5" >6.16%</td>
#       <td id="T_67e5e_row5_col6" class="data row5 col6" >100.0%</td>
#       <td id="T_67e5e_row5_col7" class="data row5 col7" >18.79%</td>
#       <td id="T_67e5e_row5_col8" class="data row5 col8" >100.0%</td>
#       <td id="T_67e5e_row5_col9" class="data row5 col9" >6.82%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row6" class="row_heading level0 row6" >702</th>
#       <td id="T_67e5e_row6_col0" class="data row6 col0" >CRCL</td>
#       <td id="T_67e5e_row6_col1" class="data row6 col1" >13</td>
#       <td id="T_67e5e_row6_col2" class="data row6 col2" >10</td>
#       <td id="T_67e5e_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_67e5e_row6_col4" class="data row6 col4" >100.0%</td>
#       <td id="T_67e5e_row6_col5" class="data row6 col5" >7.75%</td>
#       <td id="T_67e5e_row6_col6" class="data row6 col6" >100.0%</td>
#       <td id="T_67e5e_row6_col7" class="data row6 col7" >4.23%</td>
#       <td id="T_67e5e_row6_col8" class="data row6 col8" >100.0%</td>
#       <td id="T_67e5e_row6_col9" class="data row6 col9" >21.12%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row7" class="row_heading level0 row7" >2370</th>
#       <td id="T_67e5e_row7_col0" class="data row7 col0" >SPY</td>
#       <td id="T_67e5e_row7_col1" class="data row7 col1" >19</td>
#       <td id="T_67e5e_row7_col2" class="data row7 col2" >20</td>
#       <td id="T_67e5e_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_67e5e_row7_col4" class="data row7 col4" >66.7%</td>
#       <td id="T_67e5e_row7_col5" class="data row7 col5" >1.43%</td>
#       <td id="T_67e5e_row7_col6" class="data row7 col6" >100.0%</td>
#       <td id="T_67e5e_row7_col7" class="data row7 col7" >3.04%</td>
#       <td id="T_67e5e_row7_col8" class="data row7 col8" >100.0%</td>
#       <td id="T_67e5e_row7_col9" class="data row7 col9" >3.67%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row8" class="row_heading level0 row8" >2293</th>
#       <td id="T_67e5e_row8_col0" class="data row8 col0" >SOFI</td>
#       <td id="T_67e5e_row8_col1" class="data row8 col1" >11</td>
#       <td id="T_67e5e_row8_col2" class="data row8 col2" >10</td>
#       <td id="T_67e5e_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_67e5e_row8_col4" class="data row8 col4" >50.0%</td>
#       <td id="T_67e5e_row8_col5" class="data row8 col5" >0.95%</td>
#       <td id="T_67e5e_row8_col6" class="data row8 col6" >50.0%</td>
#       <td id="T_67e5e_row8_col7" class="data row8 col7" >13.11%</td>
#       <td id="T_67e5e_row8_col8" class="data row8 col8" >100.0%</td>
#       <td id="T_67e5e_row8_col9" class="data row8 col9" >13.19%</td>
#     </tr>
#     <tr>
#       <th id="T_67e5e_level0_row9" class="row_heading level0 row9" >2

# %%
# 1. Global Aggregation: Using the Raw Trade Log
# This avoids 'average of averages' for both Win Rates AND Returns.
global_strategy_raw = master_trade_log.groupby(['SMA_Param', 'BB_Param']).agg({
    'Symbol': 'count',      # Total Trade Count
    'Ret_3D': [
        ('Wins', lambda x: (x > 0).sum()),
        ('Avg_Ret', 'mean')
    ],
    'Ret_5D': [
        ('Wins', lambda x: (x > 0).sum()),
        ('Avg_Ret', 'mean')
    ],
    'Ret_10D': [
        ('Wins', lambda x: (x > 0).sum()),
        ('Avg_Ret', 'mean')
    ]
})

# 2. Flatten Multi-index columns for cleaner access
global_strategy_raw.columns = [
    'Total_Trades',
    'Wins_3D', 'Avg_3D_Ret',
    'Wins_5D', 'Avg_5D_Ret',
    'Wins_10D', 'Avg_10D_Ret'
]
global_strategy_raw = global_strategy_raw.reset_index()

# 3. Recalculate Global Win Rates from raw counts
global_strategy_raw['Win_Rate_3D'] = global_strategy_raw['Wins_3D'] / global_strategy_raw['Total_Trades']
global_strategy_raw['Win_Rate_5D'] = global_strategy_raw['Wins_5D'] / global_strategy_raw['Total_Trades']
global_strategy_raw['Win_Rate_10D'] = global_strategy_raw['Wins_10D'] / global_strategy_raw['Total_Trades']

# 4. Final Formatting & Sorting
final_cols = [
    'SMA_Param', 'BB_Param', 'Total_Trades',
    'Win_Rate_3D', 'Avg_3D_Ret',
    'Win_Rate_5D', 'Avg_5D_Ret',
    'Win_Rate_10D', 'Avg_10D_Ret'
]

global_strategy_raw = global_strategy_raw[final_cols].sort_values(by='Win_Rate_10D', ascending=False)

print("--- GLOBAL PARAMETER LEADERS (Recalculated from Raw Trade Data) ---")
display(global_strategy_raw.head(10).style.format({
    'Win_Rate_3D': '{:.1%}', 'Avg_3D_Ret': '{:.2%}',
    'Win_Rate_5D': '{:.1%}', 'Avg_5D_Ret': '{:.2%}',
    'Win_Rate_10D': '{:.1%}', 'Avg_10D_Ret': '{:.2%}'
}))
# Out:
# --- [B] GLOBAL PARAMETER LEADERS (Recalculated from Raw Trade Data) ---
# <style type="text/css">
# </style>
# <table id="T_9fc43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fc43_level0_col0" class="col_heading level0 col0" >SMA_Param</th>
#       <th id="T_9fc43_level0_col1" class="col_heading level0 col1" >BB_Param</th>
#       <th id="T_9fc43_level0_col2" class="col_heading level0 col2" >Total_Trades</th>
#       <th id="T_9fc43_level0_col3" class="col_heading level0 col3" >Win_Rate_3D</th>
#       <th id="T_9fc43_level0_col4" class="col_heading level0 col4" >Avg_3D_Ret</th>
#       <th id="T_9fc43_level0_col5" class="col_heading level0 col5" >Win_Rate_5D</th>
#       <th id="T_9fc43_level0_col6" class="col_heading level0 col6" >Avg_5D_Ret</th>
#       <th id="T_9fc43_level0_col7" class="col_heading level0 col7" >Win_Rate_10D</th>
#       <th id="T_9fc43_level0_col8" class="col_heading level0 col8" >Avg_10D_Ret</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fc43_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_9fc43_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_9fc43_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_9fc43_row0_col2" class="data row0 col2" >306</td>
#       <td id="T_9fc43_row0_col3" class="data row0 col3" >50.3%</td>
#       <td id="T_9fc43_row0_col4" class="data row0 col4" >0.42%</td>
#       <td id="T_9fc43_row0_col5" class="data row0 col5" >55.6%</td>
#       <td id="T_9fc43_row0_col6" class="data row0 col6" >0.96%</td>
#       <td id="T_9fc43_row0_col7" class="data row0 col7" >59.2%</td>
#       <td id="T_9fc43_row0_col8" class="data row0 col8" >1.75%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row1" class="row_heading level0 row1" >32</th>
#       <td id="T_9fc43_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_9fc43_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_9fc43_row1_col2" class="data row1 col2" >395</td>
#       <td id="T_9fc43_row1_col3" class="data row1 col3" >52.9%</td>
#       <td id="T_9fc43_row1_col4" class="data row1 col4" >0.86%</td>
#       <td id="T_9fc43_row1_col5" class="data row1 col5" >54.4%</td>
#       <td id="T_9fc43_row1_col6" class="data row1 col6" >1.00%</td>
#       <td id="T_9fc43_row1_col7" class="data row1 col7" >57.7%</td>
#       <td id="T_9fc43_row1_col8" class="data row1 col8" >2.17%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_9fc43_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_9fc43_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_9fc43_row2_col2" class="data row2 col2" >1843</td>
#       <td id="T_9fc43_row2_col3" class="data row2 col3" >55.2%</td>
#       <td id="T_9fc43_row2_col4" class="data row2 col4" >0.46%</td>
#       <td id="T_9fc43_row2_col5" class="data row2 col5" >54.0%</td>
#       <td id="T_9fc43_row2_col6" class="data row2 col6" >0.47%</td>
#       <td id="T_9fc43_row2_col7" class="data row2 col7" >56.4%</td>
#       <td id="T_9fc43_row2_col8" class="data row2 col8" >1.47%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_9fc43_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_9fc43_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_9fc43_row3_col2" class="data row3 col2" >199</td>
#       <td id="T_9fc43_row3_col3" class="data row3 col3" >52.3%</td>
#       <td id="T_9fc43_row3_col4" class="data row3 col4" >0.93%</td>
#       <td id="T_9fc43_row3_col5" class="data row3 col5" >51.8%</td>
#       <td id="T_9fc43_row3_col6" class="data row3 col6" >0.77%</td>
#       <td id="T_9fc43_row3_col7" class="data row3 col7" >56.3%</td>
#       <td id="T_9fc43_row3_col8" class="data row3 col8" >0.82%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row4" class="row_heading level0 row4" >28</th>
#       <td id="T_9fc43_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_9fc43_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_9fc43_row4_col2" class="data row4 col2" >1720</td>
#       <td id="T_9fc43_row4_col3" class="data row4 col3" >55.2%</td>
#       <td id="T_9fc43_row4_col4" class="data row4 col4" >0.48%</td>
#       <td id="T_9fc43_row4_col5" class="data row4 col5" >54.7%</td>
#       <td id="T_9fc43_row4_col6" class="data row4 col6" >0.56%</td>
#       <td id="T_9fc43_row4_col7" class="data row4 col7" >56.2%</td>
#       <td id="T_9fc43_row4_col8" class="data row4 col8" >1.35%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row5" class="row_heading level0 row5" >29</th>
#       <td id="T_9fc43_row5_col0" class="data row5 col0" >13</td>
#       <td id="T_9fc43_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_9fc43_row5_col2" class="data row5 col2" >370</td>
#       <td id="T_9fc43_row5_col3" class="data row5 col3" >50.8%</td>
#       <td id="T_9fc43_row5_col4" class="data row5 col4" >0.45%</td>
#       <td id="T_9fc43_row5_col5" class="data row5 col5" >53.0%</td>
#       <td id="T_9fc43_row5_col6" class="data row5 col6" >0.78%</td>
#       <td id="T_9fc43_row5_col7" class="data row5 col7" >56.2%</td>
#       <td id="T_9fc43_row5_col8" class="data row5 col8" >1.49%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_9fc43_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_9fc43_row6_col1" class="data row6 col1" >20</td>
#       <td id="T_9fc43_row6_col2" class="data row6 col2" >1666</td>
#       <td id="T_9fc43_row6_col3" class="data row6 col3" >53.7%</td>
#       <td id="T_9fc43_row6_col4" class="data row6 col4" >0.38%</td>
#       <td id="T_9fc43_row6_col5" class="data row6 col5" >53.0%</td>
#       <td id="T_9fc43_row6_col6" class="data row6 col6" >0.34%</td>
#       <td id="T_9fc43_row6_col7" class="data row6 col7" >55.8%</td>
#       <td id="T_9fc43_row6_col8" class="data row6 col8" >1.26%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row7" class="row_heading level0 row7" >27</th>
#       <td id="T_9fc43_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_9fc43_row7_col1" class="data row7 col1" >20</td>
#       <td id="T_9fc43_row7_col2" class="data row7 col2" >1497</td>
#       <td id="T_9fc43_row7_col3" class="data row7 col3" >53.6%</td>
#       <td id="T_9fc43_row7_col4" class="data row7 col4" >0.49%</td>
#       <td id="T_9fc43_row7_col5" class="data row7 col5" >53.8%</td>
#       <td id="T_9fc43_row7_col6" class="data row7 col6" >0.51%</td>
#       <td id="T_9fc43_row7_col7" class="data row7 col7" >55.7%</td>
#       <td id="T_9fc43_row7_col8" class="data row7 col8" >1.13%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row8" class="row_heading level0 row8" >31</th>
#       <td id="T_9fc43_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_9fc43_row8_col1" class="data row8 col1" >30</td>
#       <td id="T_9fc43_row8_col2" class="data row8 col2" >1620</td>
#       <td id="T_9fc43_row8_col3" class="data row8 col3" >54.6%</td>
#       <td id="T_9fc43_row8_col4" class="data row8 col4" >0.44%</td>
#       <td id="T_9fc43_row8_col5" class="data row8 col5" >54.3%</td>
#       <td id="T_9fc43_row8_col6" class="data row8 col6" >0.47%</td>
#       <td id="T_9fc43_row8_col7" class="data row8 col7" >55.4%</td>
#       <td id="T_9fc43_row8_col8" class="data row8 col8" >1.27%</td>
#     </tr>
#     <tr>
#       <th id="T_9fc43_level0_row9" class="row_heading level0 row9" >22</th>
#       <td id="T_9fc43_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_9fc43_row9_col1" class="data row9 col1" >30</td>
#       <td id="T_9fc43_row9_col2" class="data row9 col2" >1947</td>
#       <td id="T_9fc43_row9_col3" class="data row9 col3" >54.9%</td>
#       <td id="T_9fc43_row9_col4" class="data row9 col4" >0.38%</td>
#       <td id="T_9fc43_row9_col5" class="data row9 col5" >53.9%</td>
#       <td id="T_9fc43_row9_col6" class="data row9 col6" >0.43%</td>
#       <td id="T_9fc43_row9_col7" class="data row9 col7" >55.4%</td>
#       <td id="T_9fc43_row9_col8" class="data row9 col8" >1.37%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- Symbol Drill-Down Section ---
target_symbol = "NVDA"  # Change this to any symbol from your list

print(f"--- Top 10 Parameter Combinations for {target_symbol} (Sorted by Avg_10D_Ret) ---")

# Filter the performance_summary we created above
symbol_drill_down = performance_summary[performance_summary['Symbol'] == target_symbol]

# Display the results
display(symbol_drill_down[display_cols].sort_values('Avg_10D_Ret', ascending=False).head(10).style.format({
    'Win_Rate_3D': '{:.1%}', 'Avg_3D_Ret': '{:.2%}',
    'Win_Rate_5D': '{:.1%}', 'Avg_5D_Ret': '{:.2%}',
    'Win_Rate_10D': '{:.1%}', 'Avg_10D_Ret': '{:.2%}'
}))
# Out:
# --- Top 10 Parameter Combinations for NVDA (Sorted by Avg_10D_Ret) ---
# <style type="text/css">
# </style>
# <table id="T_b45cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b45cf_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_b45cf_level0_col1" class="col_heading level0 col1" >SMA_Param</th>
#       <th id="T_b45cf_level0_col2" class="col_heading level0 col2" >BB_Param</th>
#       <th id="T_b45cf_level0_col3" class="col_heading level0 col3" >Trade_Count</th>
#       <th id="T_b45cf_level0_col4" class="col_heading level0 col4" >Win_Rate_3D</th>
#       <th id="T_b45cf_level0_col5" class="col_heading level0 col5" >Avg_3D_Ret</th>
#       <th id="T_b45cf_level0_col6" class="col_heading level0 col6" >Win_Rate_5D</th>
#       <th id="T_b45cf_level0_col7" class="col_heading level0 col7" >Avg_5D_Ret</th>
#       <th id="T_b45cf_level0_col8" class="col_heading level0 col8" >Win_Rate_10D</th>
#       <th id="T_b45cf_level0_col9" class="col_heading level0 col9" >Avg_10D_Ret</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b45cf_level0_row0" class="row_heading level0 row0" >1881</th>
#       <td id="T_b45cf_row0_col0" class="data row0 col0" >NVDA</td>
#       <td id="T_b45cf_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_b45cf_row0_col2" class="data row0 col2" >30</td>
#       <td id="T_b45cf_row0_col3" class="data row0 col3" >28</td>
#       <td id="T_b45cf_row0_col4" class="data row0 col4" >67.9%</td>
#       <td id="T_b45cf_row0_col5" class="data row0 col5" >1.10%</td>
#       <td id="T_b45cf_row0_col6" class="data row0 col6" >71.4%</td>
#       <td id="T_b45cf_row0_col7" class="data row0 col7" >1.87%</td>
#       <td id="T_b45cf_row0_col8" class="data row0 col8" >64.3%</td>
#       <td id="T_b45cf_row0_col9" class="data row0 col9" >5.76%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row1" class="row_heading level0 row1" >1878</th>
#       <td id="T_b45cf_row1_col0" class="data row1 col0" >NVDA</td>
#       <td id="T_b45cf_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_b45cf_row1_col2" class="data row1 col2" >30</td>
#       <td id="T_b45cf_row1_col3" class="data row1 col3" >31</td>
#       <td id="T_b45cf_row1_col4" class="data row1 col4" >64.5%</td>
#       <td id="T_b45cf_row1_col5" class="data row1 col5" >1.02%</td>
#       <td id="T_b45cf_row1_col6" class="data row1 col6" >67.7%</td>
#       <td id="T_b45cf_row1_col7" class="data row1 col7" >1.72%</td>
#       <td id="T_b45cf_row1_col8" class="data row1 col8" >64.5%</td>
#       <td id="T_b45cf_row1_col9" class="data row1 col9" >5.56%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row2" class="row_heading level0 row2" >1884</th>
#       <td id="T_b45cf_row2_col0" class="data row2 col0" >NVDA</td>
#       <td id="T_b45cf_row2_col1" class="data row2 col1" >12</td>
#       <td id="T_b45cf_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_b45cf_row2_col3" class="data row2 col3" >28</td>
#       <td id="T_b45cf_row2_col4" class="data row2 col4" >64.3%</td>
#       <td id="T_b45cf_row2_col5" class="data row2 col5" >0.83%</td>
#       <td id="T_b45cf_row2_col6" class="data row2 col6" >60.7%</td>
#       <td id="T_b45cf_row2_col7" class="data row2 col7" >1.31%</td>
#       <td id="T_b45cf_row2_col8" class="data row2 col8" >67.9%</td>
#       <td id="T_b45cf_row2_col9" class="data row2 col9" >5.03%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row3" class="row_heading level0 row3" >1876</th>
#       <td id="T_b45cf_row3_col0" class="data row3 col0" >NVDA</td>
#       <td id="T_b45cf_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_b45cf_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_b45cf_row3_col3" class="data row3 col3" >37</td>
#       <td id="T_b45cf_row3_col4" class="data row3 col4" >64.9%</td>
#       <td id="T_b45cf_row3_col5" class="data row3 col5" >1.22%</td>
#       <td id="T_b45cf_row3_col6" class="data row3 col6" >62.2%</td>
#       <td id="T_b45cf_row3_col7" class="data row3 col7" >1.70%</td>
#       <td id="T_b45cf_row3_col8" class="data row3 col8" >59.5%</td>
#       <td id="T_b45cf_row3_col9" class="data row3 col9" >5.01%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row4" class="row_heading level0 row4" >1890</th>
#       <td id="T_b45cf_row4_col0" class="data row4 col0" >NVDA</td>
#       <td id="T_b45cf_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_b45cf_row4_col2" class="data row4 col2" >30</td>
#       <td id="T_b45cf_row4_col3" class="data row4 col3" >28</td>
#       <td id="T_b45cf_row4_col4" class="data row4 col4" >71.4%</td>
#       <td id="T_b45cf_row4_col5" class="data row4 col5" >2.06%</td>
#       <td id="T_b45cf_row4_col6" class="data row4 col6" >57.1%</td>
#       <td id="T_b45cf_row4_col7" class="data row4 col7" >1.47%</td>
#       <td id="T_b45cf_row4_col8" class="data row4 col8" >60.7%</td>
#       <td id="T_b45cf_row4_col9" class="data row4 col9" >4.90%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row5" class="row_heading level0 row5" >1887</th>
#       <td id="T_b45cf_row5_col0" class="data row5 col0" >NVDA</td>
#       <td id="T_b45cf_row5_col1" class="data row5 col1" >13</td>
#       <td id="T_b45cf_row5_col2" class="data row5 col2" >30</td>
#       <td id="T_b45cf_row5_col3" class="data row5 col3" >25</td>
#       <td id="T_b45cf_row5_col4" class="data row5 col4" >72.0%</td>
#       <td id="T_b45cf_row5_col5" class="data row5 col5" >1.90%</td>
#       <td id="T_b45cf_row5_col6" class="data row5 col6" >64.0%</td>
#       <td id="T_b45cf_row5_col7" class="data row5 col7" >2.11%</td>
#       <td id="T_b45cf_row5_col8" class="data row5 col8" >64.0%</td>
#       <td id="T_b45cf_row5_col9" class="data row5 col9" >4.84%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row6" class="row_heading level0 row6" >1880</th>
#       <td id="T_b45cf_row6_col0" class="data row6 col0" >NVDA</td>
#       <td id="T_b45cf_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_b45cf_row6_col2" class="data row6 col2" >20</td>
#       <td id="T_b45cf_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_b45cf_row6_col4" class="data row6 col4" >60.7%</td>
#       <td id="T_b45cf_row6_col5" class="data row6 col5" >0.73%</td>
#       <td id="T_b45cf_row6_col6" class="data row6 col6" >67.9%</td>
#       <td id="T_b45cf_row6_col7" class="data row6 col7" >1.51%</td>
#       <td id="T_b45cf_row6_col8" class="data row6 col8" >64.3%</td>
#       <td id="T_b45cf_row6_col9" class="data row6 col9" >4.69%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row7" class="row_heading level0 row7" >1891</th>
#       <td id="T_b45cf_row7_col0" class="data row7 col0" >NVDA</td>
#       <td id="T_b45cf_row7_col1" class="data row7 col1" >15</td>
#       <td id="T_b45cf_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_b45cf_row7_col3" class="data row7 col3" >9</td>
#       <td id="T_b45cf_row7_col4" class="data row7 col4" >66.7%</td>
#       <td id="T_b45cf_row7_col5" class="data row7 col5" >1.43%</td>
#       <td id="T_b45cf_row7_col6" class="data row7 col6" >44.4%</td>
#       <td id="T_b45cf_row7_col7" class="data row7 col7" >1.31%</td>
#       <td id="T_b45cf_row7_col8" class="data row7 col8" >55.6%</td>
#       <td id="T_b45cf_row7_col9" class="data row7 col9" >4.65%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row8" class="row_heading level0 row8" >1883</th>
#       <td id="T_b45cf_row8_col0" class="data row8 col0" >NVDA</td>
#       <td id="T_b45cf_row8_col1" class="data row8 col1" >12</td>
#       <td id="T_b45cf_row8_col2" class="data row8 col2" >20</td>
#       <td id="T_b45cf_row8_col3" class="data row8 col3" >28</td>
#       <td id="T_b45cf_row8_col4" class="data row8 col4" >50.0%</td>
#       <td id="T_b45cf_row8_col5" class="data row8 col5" >0.01%</td>
#       <td id="T_b45cf_row8_col6" class="data row8 col6" >57.1%</td>
#       <td id="T_b45cf_row8_col7" class="data row8 col7" >1.27%</td>
#       <td id="T_b45cf_row8_col8" class="data row8 col8" >75.0%</td>
#       <td id="T_b45cf_row8_col9" class="data row8 col9" >4.63%</td>
#     </tr>
#     <tr>
#       <th id="T_b45cf_level0_row9" class="row_heading level0 row9" >1873</th>
#       <

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Prepare the Aggregate Data (if not already done in Cell 2)
param_perf = master_trade_log.groupby(['SMA_Param', 'BB_Param']).agg({
    'Ret_3D': 'mean',
    'Ret_5D': 'mean',
    'Ret_10D': 'mean'
}).reset_index()

# 2. Define the horizons we want to visualize
horizons = [('3D', 'Ret_3D'), ('5D', 'Ret_5D'), ('10D', 'Ret_10D')]

print("--- PARAMETER SURFACE HEATMAPS (Average Returns) ---")

for label, col_name in horizons:
    # Pivot the data for the heatmap
    pivot_table = param_perf.pivot(index="SMA_Param", columns="BB_Param", values=col_name)

    # Create the visualization using Pandas Styler for a clean Colab output
    print(f"\n{label} Horizon Average Return:")
    display(pivot_table.style.background_gradient(cmap='RdYlGn', axis=None)
            .format("{:.2%}")
            .set_caption(f"Average {label} Return by SMA and BB Period"))

# Optional: If you prefer a more "visual" graphical heatmap using Seaborn:
# plt.figure(figsize=(10, 6))
# sns.heatmap(pivot_table, annot=True, fmt=".2%", cmap="RdYlGn")
# plt.title("10D Return Surface")
# plt.show()
# Out:
# --- PARAMETER SURFACE HEATMAPS (Average Returns) ---
#
# 3D Horizon Average Return:
# <style type="text/css">
# #T_4dab1_row0_col0, #T_4dab1_row13_col2 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_4dab1_row0_col1 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_4dab1_row0_col2, #T_4dab1_row14_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_4dab1_row1_col0 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_4dab1_row1_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_4dab1_row1_col2, #T_4dab1_row3_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_4dab1_row2_col0 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_4dab1_row2_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_4dab1_row2_col2, #T_4dab1_row15_col1 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_4dab1_row3_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_4dab1_row3_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_4dab1_row4_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4dab1_row4_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_4dab1_row4_col2, #T_4dab1_row6_col1 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_4dab1_row5_col0, #T_4dab1_row6_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_4dab1_row5_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_4dab1_row5_col2, #T_4dab1_row6_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_4dab1_row7_col0, #T_4dab1_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4dab1_row7_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_4dab1_row7_col2 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_4dab1_row8_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4dab1_row8_col1, #T_4dab1_row12_col0 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_4dab1_row8_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_4dab1_row9_col0, #T_4dab1_row10_col1 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_4dab1_row9_col1 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_4dab1_row9_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_4dab1_row10_col0 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_4dab1_row10_col2 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_4dab1_row11_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_4dab1_row11_col1 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_4dab1_row11_col2, #T_4dab1_row13_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_4dab1_row12_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_4dab1_row12_col2 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_4dab1_row13_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_4dab1_row14_col0 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_4dab1_row14_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_4dab1_row15_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_4dab1_row15_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_4dab1_row16_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_4dab1_row16_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_4dab1_row16_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_4dab1_row17_col0 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_4dab1_row17_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# </style>
# <table id="T_4dab1" class="dataframe">
#   <caption>Average 3D Return by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_4dab1_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_4dab1_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_4dab1_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4dab1_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_4dab1_row0_col0" class="data row0 col0" >0.47%</td>
#       <td id="T_4dab1_row0_col1" class="data row0 col1" >0.42%</td>
#       <td id="T_4dab1_row0_col2" class="data row0 col2" >0.32%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_4dab1_row1_col0" class="data row1 col0" >0.37%</td>
#       <td id="T_4dab1_row1_col1" class="data row1 col1" >0.28%</td>
#       <td id="T_4dab1_row1_col2" class="data row1 col2" >0.20%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_4dab1_row2_col0" class="data row2 col0" >-0.09%</td>
#       <td id="T_4dab1_row2_col1" class="data row2 col1" >0.19%</td>
#       <td id="T_4dab1_row2_col2" class="data row2 col2" >0.12%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_4dab1_row3_col0" class="data row3 col0" >-0.24%</td>
#       <td id="T_4dab1_row3_col1" class="data row3 col1" >0.20%</td>
#       <td id="T_4dab1_row3_col2" class="data row3 col2" >0.22%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_4dab1_row4_col0" class="data row4 col0" >-0.25%</td>
#       <td id="T_4dab1_row4_col1" class="data row4 col1" >0.11%</td>
#       <td id="T_4dab1_row4_col2" class="data row4 col2" >0.18%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_4dab1_row5_col0" class="data row5 col0" >-0.16%</td>
#       <td id="T_4dab1_row5_col1" class="data row5 col1" >0.19%</td>
#       <td id="T_4dab1_row5_col2" class="data row5 col2" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_4dab1_row6_col0" class="data row6 col0" >-0.16%</td>
#       <td id="T_4dab1_row6_col1" class="data row6 col1" >0.18%</td>
#       <td id="T_4dab1_row6_col2" class="data row6 col2" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_4dab1_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_4dab1_row7_col1" class="data row7 col1" >0.31%</td>
#       <td id="T_4dab1_row7_col2" class="data row7 col2" >0.38%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_4dab1_row8_col0" class="data row8 col0" >0.93%</td>
#       <td id="T_4dab1_row8_col1" class="data row8 col1" >0.38%</td>
#       <td id="T_4dab1_row8_col2" class="data row8 col2" >0.46%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_4dab1_row9_col0" class="data row9 col0" >0.42%</td>
#       <td id="T_4dab1_row9_col1" class="data row9 col1" >0.49%</td>
#       <td id="T_4dab1_row9_col2" class="data row9 col2" >0.48%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_4dab1_row10_col0" class="data row10 col0" >0.45%</td>
#       <td id="T_4dab1_row10_col1" class="data row10 col1" >0.42%</td>
#       <td id="T_4dab1_row10_col2" class="data row10 col2" >0.44%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_4dab1_row11_col0" class="data row11 col0" >0.86%</td>
#       <td id="T_4dab1_row11_col1" class="data row11 col1" >0.52%</td>
#       <td id="T_4dab1_row11_col2" class="data row11 col2" >0.51%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_4dab1_row12_col0" class="data row12 col0" >0.38%</td>
#       <td id="T_4dab1_row12_col1" class="data row12 col1" >0.65%</td>
#       <td id="T_4dab1_row12_col2" class="data row12 col2" >0.53%</td>
#     </tr>
#     <tr>
#       <th id="T_4dab1_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_4dab1_row13_col0" class="data row13 col0" >0.34%</td>
#       <td id="T_4dab1_r
# 5D Horizon Average Return:
# <style type="text/css">
# #T_1f253_row0_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_1f253_row0_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_1f253_row0_col2, #T_1f253_row5_col2, #T_1f253_row14_col1 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_1f253_row1_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_1f253_row1_col1 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_1f253_row1_col2, #T_1f253_row6_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_1f253_row2_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_1f253_row2_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_1f253_row2_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_1f253_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1f253_row3_col1 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_1f253_row3_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_1f253_row4_col0 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_1f253_row4_col1, #T_1f253_row5_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_1f253_row4_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_1f253_row5_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_1f253_row6_col0 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_1f253_row6_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_1f253_row7_col0, #T_1f253_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1f253_row7_col1, #T_1f253_row13_col0 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_1f253_row7_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_1f253_row8_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_1f253_row8_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_1f253_row8_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_1f253_row9_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_1f253_row9_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_1f253_row9_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_1f253_row10_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_1f253_row10_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_1f253_row10_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_1f253_row11_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1f253_row11_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_1f253_row11_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_1f253_row12_col0, #T_1f253_row17_col2 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_1f253_row12_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_1f253_row12_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_1f253_row13_col1 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_1f253_row13_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_1f253_row14_col0 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_1f253_row14_col2, #T_1f253_row15_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_1f253_row15_col0 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_1f253_row15_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_1f253_row16_col0, #T_1f253_row17_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_1f253_row16_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_1f253_row16_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# </style>
# <table id="T_1f253" class="dataframe">
#   <caption>Average 5D Return by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_1f253_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_1f253_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_1f253_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f253_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_1f253_row0_col0" class="data row0 col0" >0.85%</td>
#       <td id="T_1f253_row0_col1" class="data row0 col1" >0.37%</td>
#       <td id="T_1f253_row0_col2" class="data row0 col2" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_1f253_row1_col0" class="data row1 col0" >0.88%</td>
#       <td id="T_1f253_row1_col1" class="data row1 col1" >0.22%</td>
#       <td id="T_1f253_row1_col2" class="data row1 col2" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_1f253_row2_col0" class="data row2 col0" >-0.15%</td>
#       <td id="T_1f253_row2_col1" class="data row2 col1" >0.10%</td>
#       <td id="T_1f253_row2_col2" class="data row2 col2" >0.14%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_1f253_row3_col0" class="data row3 col0" >-0.39%</td>
#       <td id="T_1f253_row3_col1" class="data row3 col1" >0.07%</td>
#       <td id="T_1f253_row3_col2" class="data row3 col2" >0.20%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_1f253_row4_col0" class="data row4 col0" >-0.28%</td>
#       <td id="T_1f253_row4_col1" class="data row4 col1" >0.08%</td>
#       <td id="T_1f253_row4_col2" class="data row4 col2" >0.22%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_1f253_row5_col0" class="data row5 col0" >-0.33%</td>
#       <td id="T_1f253_row5_col1" class="data row5 col1" >0.08%</td>
#       <td id="T_1f253_row5_col2" class="data row5 col2" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_1f253_row6_col0" class="data row6 col0" >-0.16%</td>
#       <td id="T_1f253_row6_col1" class="data row6 col1" >0.19%</td>
#       <td id="T_1f253_row6_col2" class="data row6 col2" >0.32%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_1f253_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_1f253_row7_col1" class="data row7 col1" >0.33%</td>
#       <td id="T_1f253_row7_col2" class="data row7 col2" >0.43%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_1f253_row8_col0" class="data row8 col0" >0.77%</td>
#       <td id="T_1f253_row8_col1" class="data row8 col1" >0.34%</td>
#       <td id="T_1f253_row8_col2" class="data row8 col2" >0.47%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_1f253_row9_col0" class="data row9 col0" >0.96%</td>
#       <td id="T_1f253_row9_col1" class="data row9 col1" >0.51%</td>
#       <td id="T_1f253_row9_col2" class="data row9 col2" >0.56%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_1f253_row10_col0" class="data row10 col0" >0.78%</td>
#       <td id="T_1f253_row10_col1" class="data row10 col1" >0.37%</td>
#       <td id="T_1f253_row10_col2" class="data row10 col2" >0.47%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_1f253_row11_col0" class="data row11 col0" >1.00%</td>
#       <td id="T_1f253_row11_col1" class="data row11 col1" >0.53%</td>
#       <td id="T_1f253_row11_col2" class="data row11 col2" >0.54%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_1f253_row12_col0" class="data row12 col0" >0.46%</td>
#       <td id="T_1f253_row12_col1" class="data row12 col1" >0.58%</td>
#       <td id="T_1f253_row12_col2" class="data row12 col2" >0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_1f253_level0_row13" class="row_heading level0 row13" >1
# 10D Horizon Average Return:
# <style type="text/css">
# #T_75ced_row0_col0 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_75ced_row0_col1 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_75ced_row0_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_75ced_row1_col0, #T_75ced_row15_col0, #T_75ced_row17_col0 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_75ced_row1_col1 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_75ced_row1_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_75ced_row2_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_75ced_row2_col1, #T_75ced_row15_col2 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_75ced_row2_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_75ced_row3_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_75ced_row3_col1 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_75ced_row3_col2 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_75ced_row4_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_75ced_row4_col1 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_75ced_row4_col2, #T_75ced_row6_col1, #T_75ced_row7_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_75ced_row5_col0 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_75ced_row5_col1, #T_75ced_row9_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_75ced_row5_col2, #T_75ced_row11_col2 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_75ced_row6_col0 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_75ced_row6_col2 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_75ced_row7_col0, #T_75ced_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_75ced_row7_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_75ced_row8_col0, #T_75ced_row14_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_75ced_row8_col1 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_75ced_row8_col2 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_75ced_row9_col0 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_75ced_row9_col2 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_75ced_row10_col0 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_75ced_row10_col1, #T_75ced_row13_col2, #T_75ced_row16_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_75ced_row10_col2 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_75ced_row11_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_75ced_row11_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_75ced_row12_col0 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_75ced_row12_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_75ced_row12_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_75ced_row13_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_75ced_row13_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_75ced_row14_col0 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_75ced_row14_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_75ced_row15_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_75ced_row16_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_75ced_row16_col2 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_75ced_row17_col2 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75ced" class="dataframe">
#   <caption>Average 10D Return by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_75ced_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_75ced_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_75ced_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75ced_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_75ced_row0_col0" class="data row0 col0" >1.06%</td>
#       <td id="T_75ced_row0_col1" class="data row0 col1" >1.03%</td>
#       <td id="T_75ced_row0_col2" class="data row0 col2" >1.04%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_75ced_row1_col0" class="data row1 col0" >0.93%</td>
#       <td id="T_75ced_row1_col1" class="data row1 col1" >0.82%</td>
#       <td id="T_75ced_row1_col2" class="data row1 col2" >0.85%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_75ced_row2_col0" class="data row2 col0" >0.44%</td>
#       <td id="T_75ced_row2_col1" class="data row2 col1" >0.67%</td>
#       <td id="T_75ced_row2_col2" class="data row2 col2" >0.77%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_75ced_row3_col0" class="data row3 col0" >0.34%</td>
#       <td id="T_75ced_row3_col1" class="data row3 col1" >0.87%</td>
#       <td id="T_75ced_row3_col2" class="data row3 col2" >0.99%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_75ced_row4_col0" class="data row4 col0" >0.64%</td>
#       <td id="T_75ced_row4_col1" class="data row4 col1" >1.02%</td>
#       <td id="T_75ced_row4_col2" class="data row4 col2" >1.14%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_75ced_row5_col0" class="data row5 col0" >0.92%</td>
#       <td id="T_75ced_row5_col1" class="data row5 col1" >1.13%</td>
#       <td id="T_75ced_row5_col2" class="data row5 col2" >1.29%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_75ced_row6_col0" class="data row6 col0" >0.78%</td>
#       <td id="T_75ced_row6_col1" class="data row6 col1" >1.13%</td>
#       <td id="T_75ced_row6_col2" class="data row6 col2" >1.32%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_75ced_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_75ced_row7_col1" class="data row7 col1" >1.13%</td>
#       <td id="T_75ced_row7_col2" class="data row7 col2" >1.37%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_75ced_row8_col0" class="data row8 col0" >0.82%</td>
#       <td id="T_75ced_row8_col1" class="data row8 col1" >1.26%</td>
#       <td id="T_75ced_row8_col2" class="data row8 col2" >1.47%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_75ced_row9_col0" class="data row9 col0" >1.75%</td>
#       <td id="T_75ced_row9_col1" class="data row9 col1" >1.13%</td>
#       <td id="T_75ced_row9_col2" class="data row9 col2" >1.35%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_75ced_row10_col0" class="data row10 col0" >1.49%</td>
#       <td id="T_75ced_row10_col1" class="data row10 col1" >1.05%</td>
#       <td id="T_75ced_row10_col2" class="data row10 col2" >1.27%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_75ced_row11_col0" class="data row11 col0" >2.17%</td>
#       <td id="T_75ced_row11_col1" class="data row11 col1" >1.19%</td>
#       <td id="T_75ced_row11_col2" class="data row11 col2" >1.29%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_75ced_row12_col0" class="data row12 col0" >1.94%</td>
#       <td id="T_75ced_row12_col1" class="data row12 col1" >1.07%</td>
#       <td id="T_75ced_row12_col2" class="data row12 col2" >1.12%</td>
#     </tr>
#     <tr>
#       <th id="T_75ced_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_75ced_row13_col0" class="data row13 col0" >1.45%</td>
#       <td id="T_75ced_row13

# %%
# 1. Prepare the Win Rate Aggregate Data
# We calculate the mean of the boolean (Return > 0) to get the percentage of wins
win_rate_perf = master_trade_log.groupby(['SMA_Param', 'BB_Param']).agg({
    'Ret_3D': lambda x: (x > 0).mean(),
    'Ret_5D': lambda x: (x > 0).mean(),
    'Ret_10D': lambda x: (x > 0).mean()
}).reset_index()

# 2. Define the horizons for visualization
horizons = [('3-Day', 'Ret_3D'), ('5-Day', 'Ret_5D'), ('10-Day', 'Ret_10D')]

print("--- PARAMETER SURFACE HEATMAPS (Win Rate %) ---")
print("Focus: Probability of a positive return across the portfolio.")

for label, col_name in horizons:
    # Pivot the data for the heatmap
    pivot_win_rate = win_rate_perf.pivot(index="SMA_Param", columns="BB_Param", values=col_name)

    print(f"\n{label} Win Rate Surface:")
    # Using a 0.5 (50%) midpoint for the gradient helps highlight 'Edge' vs 'Coin Flip'
    display(pivot_win_rate.style.background_gradient(cmap='RdYlGn', vmin=0.45, vmax=0.65, axis=None)
            .format("{:.1%}")
            .set_caption(f"{label} Win Rate by SMA and BB Period"))
# Out:
# --- PARAMETER SURFACE HEATMAPS (Win Rate %) ---
# Focus: Probability of a positive return across the portfolio.
#
# 3-Day Win Rate Surface:
# <style type="text/css">
# #T_94e1b_row0_col0 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_94e1b_row0_col1, #T_94e1b_row17_col2 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_94e1b_row0_col2 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_94e1b_row1_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_94e1b_row1_col1, #T_94e1b_row3_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_94e1b_row1_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_94e1b_row2_col0, #T_94e1b_row13_col0 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_94e1b_row2_col1 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_94e1b_row2_col2, #T_94e1b_row14_col1 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_94e1b_row3_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_94e1b_row3_col1 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_94e1b_row4_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_94e1b_row4_col1, #T_94e1b_row8_col0 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_94e1b_row4_col2, #T_94e1b_row6_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_94e1b_row5_col0 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_94e1b_row5_col1, #T_94e1b_row10_col1 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_94e1b_row5_col2, #T_94e1b_row8_col1, #T_94e1b_row9_col1 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_94e1b_row6_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_94e1b_row6_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_94e1b_row7_col0, #T_94e1b_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_94e1b_row7_col1, #T_94e1b_row14_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_94e1b_row7_col2 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_94e1b_row8_col2 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_94e1b_row9_col0 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_94e1b_row9_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_94e1b_row10_col0 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_94e1b_row10_col2 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_94e1b_row11_col0, #T_94e1b_row11_col1, #T_94e1b_row16_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_94e1b_row11_col2, #T_94e1b_row12_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_94e1b_row12_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_94e1b_row12_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_94e1b_row13_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_94e1b_row13_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_94e1b_row14_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_94e1b_row15_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_94e1b_row15_col1 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_94e1b_row15_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_94e1b_row16_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_94e1b_row16_col1 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_94e1b_row17_col0 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94e1b" class="dataframe">
#   <caption>3-Day Win Rate by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_94e1b_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_94e1b_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_94e1b_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94e1b_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_94e1b_row0_col0" class="data row0 col0" >50.9%</td>
#       <td id="T_94e1b_row0_col1" class="data row0 col1" >53.0%</td>
#       <td id="T_94e1b_row0_col2" class="data row0 col2" >52.3%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_94e1b_row1_col0" class="data row1 col0" >50.0%</td>
#       <td id="T_94e1b_row1_col1" class="data row1 col1" >52.5%</td>
#       <td id="T_94e1b_row1_col2" class="data row1 col2" >52.0%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_94e1b_row2_col0" class="data row2 col0" >48.8%</td>
#       <td id="T_94e1b_row2_col1" class="data row2 col1" >51.9%</td>
#       <td id="T_94e1b_row2_col2" class="data row2 col2" >51.6%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_94e1b_row3_col0" class="data row3 col0" >48.0%</td>
#       <td id="T_94e1b_row3_col1" class="data row3 col1" >52.1%</td>
#       <td id="T_94e1b_row3_col2" class="data row3 col2" >52.4%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_94e1b_row4_col0" class="data row4 col0" >47.8%</td>
#       <td id="T_94e1b_row4_col1" class="data row4 col1" >52.2%</td>
#       <td id="T_94e1b_row4_col2" class="data row4 col2" >52.6%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_94e1b_row5_col0" class="data row5 col0" >47.9%</td>
#       <td id="T_94e1b_row5_col1" class="data row5 col1" >52.7%</td>
#       <td id="T_94e1b_row5_col2" class="data row5 col2" >53.6%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_94e1b_row6_col0" class="data row6 col0" >48.2%</td>
#       <td id="T_94e1b_row6_col1" class="data row6 col1" >52.5%</td>
#       <td id="T_94e1b_row6_col2" class="data row6 col2" >53.8%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_94e1b_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_94e1b_row7_col1" class="data row7 col1" >53.5%</td>
#       <td id="T_94e1b_row7_col2" class="data row7 col2" >54.9%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_94e1b_row8_col0" class="data row8 col0" >52.3%</td>
#       <td id="T_94e1b_row8_col1" class="data row8 col1" >53.7%</td>
#       <td id="T_94e1b_row8_col2" class="data row8 col2" >55.2%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_94e1b_row9_col0" class="data row9 col0" >50.3%</td>
#       <td id="T_94e1b_row9_col1" class="data row9 col1" >53.6%</td>
#       <td id="T_94e1b_row9_col2" class="data row9 col2" >55.2%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_94e1b_row10_col0" class="data row10 col0" >50.8%</td>
#       <td id="T_94e1b_row10_col1" class="data row10 col1" >52.7%</td>
#       <td id="T_94e1b_row10_col2" class="data row10 col2" >54.6%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_94e1b_row11_col0" class="data row11 col0" >52.9%</td>
#       <td id="T_94e1b_row11_col1" class="data row11 col1" >52.9%</td>
#       <td id="T_94e1b_row11_col2" class="data row11 col2" >54.2%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_94e1b_row12_col0" class="data row12 col0" >49.6%</td>
#       <td id="T_94e1b_row12_col1" class="data row12 col1" >53.1%</td>
#       <td id="T_94e1b_row12_col2" class="data row12 col2" >54.2%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_94e1b_row13_col0" class="data row13 col0" >48.8%</td>
#       <td id="T_94e1b_row13_col1" class="data row13 col1" >52.9%</td>
#       <td id="T_94e1b_row13_col2" class="data row13 col2" >54.5%</td>
#     </tr>
#     <tr>
#       <th id="T_94e1b_
# 5-Day Win Rate Surface:
# <style type="text/css">
# #T_e1ddb_row0_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_e1ddb_row0_col1 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_e1ddb_row0_col2, #T_e1ddb_row8_col0 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_e1ddb_row1_col0, #T_e1ddb_row6_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_e1ddb_row1_col1 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_e1ddb_row1_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_e1ddb_row2_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_e1ddb_row2_col1 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_e1ddb_row2_col2 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_e1ddb_row3_col0 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_e1ddb_row3_col1 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_e1ddb_row3_col2, #T_e1ddb_row4_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_e1ddb_row4_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_e1ddb_row4_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_e1ddb_row5_col0 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_e1ddb_row5_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_e1ddb_row5_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_e1ddb_row6_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_e1ddb_row6_col2, #T_e1ddb_row10_col1, #T_e1ddb_row14_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_e1ddb_row7_col0, #T_e1ddb_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e1ddb_row7_col1, #T_e1ddb_row12_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_e1ddb_row7_col2, #T_e1ddb_row12_col1 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_e1ddb_row8_col1, #T_e1ddb_row10_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_e1ddb_row8_col2 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_e1ddb_row9_col0 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_e1ddb_row9_col1, #T_e1ddb_row13_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_e1ddb_row9_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_e1ddb_row10_col2, #T_e1ddb_row16_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_e1ddb_row11_col0 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_e1ddb_row11_col1, #T_e1ddb_row15_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_e1ddb_row11_col2, #T_e1ddb_row16_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_e1ddb_row12_col2 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_e1ddb_row13_col0 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_e1ddb_row13_col2 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_e1ddb_row14_col0 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_e1ddb_row14_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_e1ddb_row15_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_e1ddb_row15_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_e1ddb_row16_col0 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_e1ddb_row17_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_e1ddb_row17_col2 {
#   background-color: #feea9b;
#   color: #000000;
# }
# </style>
# <table id="T_e1ddb" class="dataframe">
#   <caption>5-Day Win Rate by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_e1ddb_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_e1ddb_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_e1ddb_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1ddb_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e1ddb_row0_col0" class="data row0 col0" >50.1%</td>
#       <td id="T_e1ddb_row0_col1" class="data row0 col1" >52.1%</td>
#       <td id="T_e1ddb_row0_col2" class="data row0 col2" >51.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_e1ddb_row1_col0" class="data row1 col0" >50.0%</td>
#       <td id="T_e1ddb_row1_col1" class="data row1 col1" >51.5%</td>
#       <td id="T_e1ddb_row1_col2" class="data row1 col2" >51.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e1ddb_row2_col0" class="data row2 col0" >48.5%</td>
#       <td id="T_e1ddb_row2_col1" class="data row2 col1" >50.5%</td>
#       <td id="T_e1ddb_row2_col2" class="data row2 col2" >51.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_e1ddb_row3_col0" class="data row3 col0" >48.4%</td>
#       <td id="T_e1ddb_row3_col1" class="data row3 col1" >51.4%</td>
#       <td id="T_e1ddb_row3_col2" class="data row3 col2" >51.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_e1ddb_row4_col0" class="data row4 col0" >49.1%</td>
#       <td id="T_e1ddb_row4_col1" class="data row4 col1" >51.8%</td>
#       <td id="T_e1ddb_row4_col2" class="data row4 col2" >52.2%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_e1ddb_row5_col0" class="data row5 col0" >49.2%</td>
#       <td id="T_e1ddb_row5_col1" class="data row5 col1" >52.4%</td>
#       <td id="T_e1ddb_row5_col2" class="data row5 col2" >52.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_e1ddb_row6_col0" class="data row6 col0" >50.0%</td>
#       <td id="T_e1ddb_row6_col1" class="data row6 col1" >52.4%</td>
#       <td id="T_e1ddb_row6_col2" class="data row6 col2" >53.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_e1ddb_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_e1ddb_row7_col1" class="data row7 col1" >53.3%</td>
#       <td id="T_e1ddb_row7_col2" class="data row7 col2" >53.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_e1ddb_row8_col0" class="data row8 col0" >51.8%</td>
#       <td id="T_e1ddb_row8_col1" class="data row8 col1" >53.0%</td>
#       <td id="T_e1ddb_row8_col2" class="data row8 col2" >54.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_e1ddb_row9_col0" class="data row9 col0" >55.6%</td>
#       <td id="T_e1ddb_row9_col1" class="data row9 col1" >53.8%</td>
#       <td id="T_e1ddb_row9_col2" class="data row9 col2" >54.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_e1ddb_row10_col0" class="data row10 col0" >53.0%</td>
#       <td id="T_e1ddb_row10_col1" class="data row10 col1" >53.1%</td>
#       <td id="T_e1ddb_row10_col2" class="data row10 col2" >54.3%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_e1ddb_row11_col0" class="data row11 col0" >54.4%</td>
#       <td id="T_e1ddb_row11_col1" class="data row11 col1" >52.8%</td>
#       <td id="T_e1ddb_row11_col2" class="data row11 col2" >53.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_e1ddb_row12_col0" class="data row12 col0" >53.2%</td>
#       <td id="T_e1ddb_row12_col1" class="data row12 col1" >53.9%</td>
#       <td id="T_e1ddb_row12_col2" class="data row12 col2" >54.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e1ddb_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_e1ddb_row13_col0" class="data row13 col0" >51.7%</td>
#       <td id="T_e1ddb_row13_col1" class="data row13 col1" >53.8%</td>
#       <td id="T_e1ddb_row13_col2" class="data row13 col2" >55
# 10-Day Win Rate Surface:
# <style type="text/css">
# #T_4ac1f_row0_col0, #T_4ac1f_row1_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_4ac1f_row0_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_4ac1f_row0_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_4ac1f_row1_col0 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_4ac1f_row1_col1, #T_4ac1f_row3_col1, #T_4ac1f_row6_col0 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_4ac1f_row2_col0, #T_4ac1f_row17_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_4ac1f_row2_col1, #T_4ac1f_row14_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_4ac1f_row2_col2 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_4ac1f_row3_col0 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_4ac1f_row3_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_4ac1f_row4_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_4ac1f_row4_col1 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_4ac1f_row4_col2 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_4ac1f_row5_col0 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_4ac1f_row5_col1 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_4ac1f_row5_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_4ac1f_row6_col1, #T_4ac1f_row7_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_4ac1f_row6_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_4ac1f_row7_col0, #T_4ac1f_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4ac1f_row7_col2, #T_4ac1f_row10_col2, #T_4ac1f_row11_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_4ac1f_row8_col0 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_4ac1f_row8_col1 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_4ac1f_row8_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_4ac1f_row9_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_4ac1f_row9_col1 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_4ac1f_row9_col2, #T_4ac1f_row10_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_4ac1f_row10_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_4ac1f_row11_col0 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_4ac1f_row11_col2 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_4ac1f_row12_col0 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_4ac1f_row12_col1 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_4ac1f_row12_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_4ac1f_row13_col0 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_4ac1f_row13_col1, #T_4ac1f_row15_col1 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_4ac1f_row13_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_4ac1f_row14_col1 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_4ac1f_row14_col2, #T_4ac1f_row15_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_4ac1f_row15_col0 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_4ac1f_row16_col0 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_4ac1f_row16_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_4ac1f_row16_col2 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_4ac1f_row17_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# </style>
# <table id="T_4ac1f" class="dataframe">
#   <caption>10-Day Win Rate by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_4ac1f_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_4ac1f_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_4ac1f_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ac1f_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_4ac1f_row0_col0" class="data row0 col0" >52.8%</td>
#       <td id="T_4ac1f_row0_col1" class="data row0 col1" >53.5%</td>
#       <td id="T_4ac1f_row0_col2" class="data row0 col2" >53.3%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_4ac1f_row1_col0" class="data row1 col0" >51.8%</td>
#       <td id="T_4ac1f_row1_col1" class="data row1 col1" >52.6%</td>
#       <td id="T_4ac1f_row1_col2" class="data row1 col2" >52.8%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_4ac1f_row2_col0" class="data row2 col0" >50.7%</td>
#       <td id="T_4ac1f_row2_col1" class="data row2 col1" >51.9%</td>
#       <td id="T_4ac1f_row2_col2" class="data row2 col2" >52.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_4ac1f_row3_col0" class="data row3 col0" >50.5%</td>
#       <td id="T_4ac1f_row3_col1" class="data row3 col1" >52.5%</td>
#       <td id="T_4ac1f_row3_col2" class="data row3 col2" >52.9%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_4ac1f_row4_col0" class="data row4 col0" >51.1%</td>
#       <td id="T_4ac1f_row4_col1" class="data row4 col1" >53.3%</td>
#       <td id="T_4ac1f_row4_col2" class="data row4 col2" >53.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_4ac1f_row5_col0" class="data row5 col0" >52.1%</td>
#       <td id="T_4ac1f_row5_col1" class="data row5 col1" >53.8%</td>
#       <td id="T_4ac1f_row5_col2" class="data row5 col2" >54.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_4ac1f_row6_col0" class="data row6 col0" >52.6%</td>
#       <td id="T_4ac1f_row6_col1" class="data row6 col1" >54.5%</td>
#       <td id="T_4ac1f_row6_col2" class="data row6 col2" >55.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_4ac1f_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_4ac1f_row7_col1" class="data row7 col1" >54.6%</td>
#       <td id="T_4ac1f_row7_col2" class="data row7 col2" >55.4%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_4ac1f_row8_col0" class="data row8 col0" >56.3%</td>
#       <td id="T_4ac1f_row8_col1" class="data row8 col1" >55.8%</td>
#       <td id="T_4ac1f_row8_col2" class="data row8 col2" >56.4%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_4ac1f_row9_col0" class="data row9 col0" >59.2%</td>
#       <td id="T_4ac1f_row9_col1" class="data row9 col1" >55.7%</td>
#       <td id="T_4ac1f_row9_col2" class="data row9 col2" >56.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_4ac1f_row10_col0" class="data row10 col0" >56.2%</td>
#       <td id="T_4ac1f_row10_col1" class="data row10 col1" >55.1%</td>
#       <td id="T_4ac1f_row10_col2" class="data row10 col2" >55.4%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_4ac1f_row11_col0" class="data row11 col0" >57.7%</td>
#       <td id="T_4ac1f_row11_col1" class="data row11 col1" >55.4%</td>
#       <td id="T_4ac1f_row11_col2" class="data row11 col2" >55.3%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_4ac1f_row12_col0" class="data row12 col0" >54.6%</td>
#       <td id="T_4ac1f_row12_col1" class="data row12 col1" >53.1%</td>
#       <td id="T_4ac1f_row12_col2" class="data row12 col2" >53.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4ac1f_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_4ac1f_row13_col0" class="data row13 col0" >53.8%</td>
#       <td id="T_4ac1f_row13_col1" class="data row13 col1" >53.2%</td>
#       <td

# %%
# 1. Create a copy for export to keep the original data intact
export_df = global_strategy_raw.copy()

# 2. Round all numerical columns to 4 decimal places
# This ensures that Win Rates (0.6543 -> 0.65) and Returns (0.0123 -> 0.01) are consistent
export_df = export_df.round(4)

# 3. Rename columns for the final report
export_df = export_df.rename(columns={
    'SMA_Param': 'SMA',
    'BB_Param': 'BB',
    'Total_Trades': 'Trades'
})

# 4. Export to CSV string
# float_format="%.4f" is a safety measure to ensure trailing zeros are kept (e.g., 0.50)
csv_output = export_df.to_csv(index=False, float_format="%.4f")

print("--- COPY AND PASTE THIS TO GEMINI ---")
print(csv_output)
# Out:
# --- COPY AND PASTE THIS TO GEMINI ---
# SMA,BB,Trades,Win_Rate_3D,Avg_3D_Ret,Win_Rate_5D,Avg_5D_Ret,Win_Rate_10D,Avg_10D_Ret
# 12,10,306,0.5033,0.0042,0.5556,0.0096,0.5915,0.0175
# 14,10,395,0.5291,0.0086,0.5443,0.0100,0.5772,0.0217
# 11,30,1843,0.5524,0.0046,0.5399,0.0047,0.5643,0.0147
# 11,10,199,0.5226,0.0093,0.5176,0.0077,0.5628,0.0082
# 12,30,1720,0.5523,0.0048,0.5471,0.0056,0.5622,0.0135
# 13,10,370,0.5081,0.0045,0.5297,0.0078,0.5622,0.0149
# 11,20,1666,0.5366,0.0038,0.5300,0.0034,0.5582,0.0126
# 12,20,1497,0.5364,0.0049,0.5377,0.0051,0.5571,0.0113
# 13,30,1620,0.5463,0.0044,0.5426,0.0047,0.5537,0.0127
# 10,30,1947,0.5485,0.0038,0.5388,0.0043,0.5537,0.0137
# 14,20,1196,0.5293,0.0052,0.5276,0.0053,0.5535,0.0119
# 14,30,1547,0.5417,0.0051,0.5372,0.0054,0.5527,0.0129
# 9,30,2083,0.5377,0.0029,0.5305,0.0032,0.5521,0.0132
# 13,20,1344,0.5268,0.0042,0.5305,0.0037,0.5506,0.0105
# 15,10,421,0.4964,0.0038,0.5321,0.0046,0.5463,0.0194
# 10,20,1804,0.5349,0.0031,0.5327,0.0033,0.5460,0.0113
# 9,20,1973,0.5251,0.0018,0.5241,0.0019,0.5454,0.0113
# 8,30,2260,0.5363,0.0029,0.5288,0.0029,0.5416,0.0129
# 8,20,2168,0.5272,0.0019,0.5244,0.0008,0.5383,0.0113
# 16,10,424,0.4882,0.0034,0.5165,0.0032,0.5377,0.0145
# 16,30,1383,0.5452,0.0047,0.5539,0.0060,0.5372,0.0105
# 7,30,2462,0.5256,0.0018,0.5215,0.0022,0.5361,0.0114
# 3,20,4402,0.5298,0.0042,0.5209,0.0037,0.5354,0.0103
# 15,30,1443,0.5419,0.0053,0.5468,0.0058,0.5350,0.0112
# 3,30,4345,0.5227,0.0032,0.5176,0.0028,0.5335,0.0104
# 7,20,2413,0.5222,0.0011,0.5184,0.0008,0.5325,0.0102
# 16,20,876,0.5285,0.0050,0.5377,0.0041,0.5320,0.0089
# 18,20,455,0.5143,0.0012,0.5275,0.0027,0.5319,0.0075
# 15,20,1041,0.5312,0.0065,0.5389,0.0058,0.5312,0.0107
# 6,30,2697,0.5243,0.0022,0.5184,0.0020,0.5291,0.0099
# 3,10,4295,0.5090,0.0047,0.5006,0.0085,0.5276,0.0106
# 4,30,3562,0.5197,0.0020,0.5152,0.0019,0.5275,0.0085
# 18,30,1207,0.5336,0.0017,0.5460,0.0044,0.5261,0.0067
# 17,30,1291,0.5345,0.0030,0.5445,0.0044,0.5259,0.0082
# 9,10,546,0.4817,-0.0016,0.5000,-0.0016,0.5256,0.0078
# 4,20,3590,0.5245,0.0028,0.5148,0.0022,0.5256,0.0082
# 6,20,2680,0.5213,0.0020,0.5138,0.0007,0.5254,0.0087
# 19,20,223,0.5022,0.0021,0.5426,0.0023,0.5247,0.0020
# 17,20,686,0.5160,0.0031,0.5306,0.0029,0.5233,0.0080
# 5,30,3071,0.5158,0.0012,0.5103,0.0014,0.5217,0.0077
# 8,10,1056,0.4792,-0.0016,0.4924,-0.0033,0.5208,0.0092
# 5,20,3063,0.5194,0.0019,0.5054,0.0010,0.5194,0.0067
# 17,10,445,0.4697,0.0010,0.5079,0.0026,0.5191,0.0134
# 4,10,3315,0.5005,0.0037,0.4998,0.0088,0.5179,0.0093
# 20,30,1055,0.5299,0.0010,0.5365,0.0045,0.5128,0.0051
# 19,30,1121,0.5290,0.0009,0.5370,0.0027,0.5112,0.0039
# 7,10,1586,0.4779,-0.0025,0.4905,-0.0028,0.5107,0.0064
# 20,10,463,0.4773,-0.0008,0.4536,-0.0029,0.5076,0.0093
# 5,10,2606,0.4881,-0.0009,0.4847,-0.0015,0.5073,0.0044
# 18,10,450,0.4600,-0.0012,0.4867,-0.0005,0.5067,0.0093
# 6,10,2031,0.4801,-0.0024,0.4840,-0.0039,0.5052,0.0034
# 19,10,452,0.4690,-0.0019,0.4757,-0.0029,0.5044,0.0105

# %%
# 1. Aggregate Advanced Risk Metrics from Raw Data
# We focus on the 10-Day window as it showed the highest potential for spreads
stress_test = master_trade_log.groupby(['SMA_Param', 'BB_Param'])['Ret_10D'].agg([
    ('Trades', 'count'),
    ('Avg_Ret', 'mean'),
    ('Median_Ret', 'median'),
    ('Std_Dev', 'std'),
    ('Win_Rate', lambda x: (x > 0).mean())
]).reset_index()

# 2. Calculate Expectancy Score (Assuming 1:1 Risk/Reward Ratio)
# Formula: (WinRate * 1) - (LossRate * 1)
# A score of 0.10 means you expect to make $0.10 for every $1.00 risked over time.
stress_test['Expectancy_Score'] = (stress_test['Win_Rate'] * 2) - 1

# 3. Sort by Expectancy Score
stress_test = stress_test.sort_values('Expectancy_Score', ascending=False)

print("--- STRATEGY EXPECTANCY & STRESS TEST (10-Day Window) ---")
print("Focus: Finding the most 'reliable' parameters, not just the 'luckiest'.")

display(stress_test.head(10).style.format({
    'Avg_Ret': '{:.2%}',
    'Median_Ret': '{:.2%}',
    'Std_Dev': '{:.2%}',
    'Win_Rate': '{:.1%}',
    'Expectancy_Score': '{:.3f}'
}).background_gradient(subset=['Expectancy_Score'], cmap='Greens'))
# Out:
# --- STRATEGY EXPECTANCY & STRESS TEST (10-Day Window) ---
# Focus: Finding the most 'reliable' parameters, not just the 'luckiest'.
# <style type="text/css">
# #T_17edb_row0_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_17edb_row1_col7 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_17edb_row2_col7 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_17edb_row3_col7 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_17edb_row4_col7, #T_17edb_row5_col7 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_17edb_row6_col7 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_17edb_row7_col7 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_17edb_row8_col7, #T_17edb_row9_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_17edb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17edb_level0_col0" class="col_heading level0 col0" >SMA_Param</th>
#       <th id="T_17edb_level0_col1" class="col_heading level0 col1" >BB_Param</th>
#       <th id="T_17edb_level0_col2" class="col_heading level0 col2" >Trades</th>
#       <th id="T_17edb_level0_col3" class="col_heading level0 col3" >Avg_Ret</th>
#       <th id="T_17edb_level0_col4" class="col_heading level0 col4" >Median_Ret</th>
#       <th id="T_17edb_level0_col5" class="col_heading level0 col5" >Std_Dev</th>
#       <th id="T_17edb_level0_col6" class="col_heading level0 col6" >Win_Rate</th>
#       <th id="T_17edb_level0_col7" class="col_heading level0 col7" >Expectancy_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17edb_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_17edb_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_17edb_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_17edb_row0_col2" class="data row0 col2" >305</td>
#       <td id="T_17edb_row0_col3" class="data row0 col3" >1.75%</td>
#       <td id="T_17edb_row0_col4" class="data row0 col4" >1.16%</td>
#       <td id="T_17edb_row0_col5" class="data row0 col5" >10.84%</td>
#       <td id="T_17edb_row0_col6" class="data row0 col6" >59.2%</td>
#       <td id="T_17edb_row0_col7" class="data row0 col7" >0.183</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row1" class="row_heading level0 row1" >32</th>
#       <td id="T_17edb_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_17edb_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_17edb_row1_col2" class="data row1 col2" >392</td>
#       <td id="T_17edb_row1_col3" class="data row1 col3" >2.17%</td>
#       <td id="T_17edb_row1_col4" class="data row1 col4" >0.88%</td>
#       <td id="T_17edb_row1_col5" class="data row1 col5" >10.89%</td>
#       <td id="T_17edb_row1_col6" class="data row1 col6" >57.7%</td>
#       <td id="T_17edb_row1_col7" class="data row1 col7" >0.154</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_17edb_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_17edb_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_17edb_row2_col2" class="data row2 col2" >1836</td>
#       <td id="T_17edb_row2_col3" class="data row2 col3" >1.47%</td>
#       <td id="T_17edb_row2_col4" class="data row2 col4" >1.00%</td>
#       <td id="T_17edb_row2_col5" class="data row2 col5" >11.60%</td>
#       <td id="T_17edb_row2_col6" class="data row2 col6" >56.4%</td>
#       <td id="T_17edb_row2_col7" class="data row2 col7" >0.129</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_17edb_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_17edb_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_17edb_row3_col2" class="data row3 col2" >198</td>
#       <td id="T_17edb_row3_col3" class="data row3 col3" >0.82%</td>
#       <td id="T_17edb_row3_col4" class="data row3 col4" >0.97%</td>
#       <td id="T_17edb_row3_col5" class="data row3 col5" >9.84%</td>
#       <td id="T_17edb_row3_col6" class="data row3 col6" >56.3%</td>
#       <td id="T_17edb_row3_col7" class="data row3 col7" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row4" class="row_heading level0 row4" >28</th>
#       <td id="T_17edb_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_17edb_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_17edb_row4_col2" class="data row4 col2" >1713</td>
#       <td id="T_17edb_row4_col3" class="data row4 col3" >1.35%</td>
#       <td id="T_17edb_row4_col4" class="data row4 col4" >1.00%</td>
#       <td id="T_17edb_row4_col5" class="data row4 col5" >11.12%</td>
#       <td id="T_17edb_row4_col6" class="data row4 col6" >56.2%</td>
#       <td id="T_17edb_row4_col7" class="data row4 col7" >0.124</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row5" class="row_heading level0 row5" >29</th>
#       <td id="T_17edb_row5_col0" class="data row5 col0" >13</td>
#       <td id="T_17edb_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_17edb_row5_col2" class="data row5 col2" >368</td>
#       <td id="T_17edb_row5_col3" class="data row5 col3" >1.49%</td>
#       <td id="T_17edb_row5_col4" class="data row5 col4" >0.80%</td>
#       <td id="T_17edb_row5_col5" class="data row5 col5" >10.97%</td>
#       <td id="T_17edb_row5_col6" class="data row5 col6" >56.2%</td>
#       <td id="T_17edb_row5_col7" class="data row5 col7" >0.124</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_17edb_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_17edb_row6_col1" class="data row6 col1" >20</td>
#       <td id="T_17edb_row6_col2" class="data row6 col2" >1660</td>
#       <td id="T_17edb_row6_col3" class="data row6 col3" >1.26%</td>
#       <td id="T_17edb_row6_col4" class="data row6 col4" >0.84%</td>
#       <td id="T_17edb_row6_col5" class="data row6 col5" >11.54%</td>
#       <td id="T_17edb_row6_col6" class="data row6 col6" >55.8%</td>
#       <td id="T_17edb_row6_col7" class="data row6 col7" >0.116</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row7" class="row_heading level0 row7" >27</th>
#       <td id="T_17edb_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_17edb_row7_col1" class="data row7 col1" >20</td>
#       <td id="T_17edb_row7_col2" class="data row7 col2" >1492</td>
#       <td id="T_17edb_row7_col3" class="data row7 col3" >1.13%</td>
#       <td id="T_17edb_row7_col4" class="data row7 col4" >0.87%</td>
#       <td id="T_17edb_row7_col5" class="data row7 col5" >11.12%</td>
#       <td id="T_17edb_row7_col6" class="data row7 col6" >55.7%</td>
#       <td id="T_17edb_row7_col7" class="data row7 col7" >0.114</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row8" class="row_heading level0 row8" >31</th>
#       <td id="T_17edb_row8_col0" class="data row8 col0" >13</td>
#       <td id="T_17edb_row8_col1" class="data row8 col1" >30</td>
#       <td id="T_17edb_row8_col2" class="data row8 col2" >1614</td>
#       <td id="T_17edb_row8_col3" class="data row8 col3" >1.27%</td>
#       <td id="T_17edb_row8_col4" class="data row8 col4" >0.95%</td>
#       <td id="T_17edb_row8_col5" class="data row8 col5" >11.34%</td>
#       <td id="T_17edb_row8_col6" class="data row8 col6" >55.4%</td>
#       <td id="T_17edb_row8_col7" class="data row8 col7" >0.107</td>
#     </tr>
#     <tr>
#       <th id="T_17edb_level0_row9" class="row_heading level0 row9" >22</th>
#       <td id="T_17edb_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_17edb_row9_col1" class="data row9 col1" >30</td>
#       <td id="T_17edb_row9_col2" class="data row9 col2" >1937</td>
#       <td id="T_17edb_row9_col3" class="data row9 col3" >1.37%</td>
#       <td id="T_17edb_row9_col4" class="data row9 col4" >0.92%</td>
#       <td id="T_17edb_row9_col5" class="data row9 col5" >11.39%</td>
#       <td id="T_17edb_row9_col6" class="data row9 col6" >55.4%</td>
#       <td id="T_17edb_row9_col7" class="data row9 col7" >0.107</td>
#     </tr>
#   </tbody>
# </table>
