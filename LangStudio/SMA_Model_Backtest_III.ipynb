# %% [markdown]
# <a href="https://colab.research.google.com/github/jhenningsen/Equity_Analysis/blob/main/LangStudio/SMA_Model_Backtest_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os

# Point to your Drive folder
drive_lib = '/content/drive/My Drive/python_libs'
if drive_lib not in sys.path:
    sys.path.insert(0, drive_lib)

try:
    import pandas_ta as ta
    import pandas as pd
    import numpy as np
    print("Success! Environment is ready for 2022 analysis.")
    print(f"Pandas Version: {pd.__version__}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Success! Environment is ready for 2022 analysis.
# Pandas Version: 2.2.2

# %%
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import numpy as np

# 1. Configuration
SMA_RANGE = range(3, 21)
BB_PERIODS = [10, 20, 30]
SYMBOLS = ["TSLA", "SPY", "QQQ", "NVDA", "META", "MSTR", "COIN", "GLD", "AMD", "SLV", "PLTR", "MSFT", "ORCL", "IWM", "AAPL", "AVGO", "AMZN", "UNH", "NFLX", "MU", "GOOGL", "TSM", "LULU", "CRWV", "GOOG", "IBIT", "JPM", "HOOD", "GDX", "ADBE", "NOW", "APP", "GS", "WOLF", "BABA", "IREN", "COST", "INTC", "LLY", "CRCL", "CVNA", "SNDK", "OKLO", "SMH", "BA", "BMNR", "ASTS", "NBIS", "SOFI", "BE"]

# 2. Optimized Data Cache
print("Fetching fresh data...")
data_cache = {}
for s in SYMBOLS:
    df = yf.download(s, period="5y", interval="1d", progress=False, auto_adjust=True)
    #df = yf.download(s, start="2021-12-01", end="2023-01-01", interval="1d", progress=False, auto_adjust=True)
    if not df.empty:
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(0)
        data_cache[s] = df

# 3. Generate Raw Trades with Technical Audit Columns
all_trades_list = []
print("Generating Technical Audit Logs...")

for sma_val in SMA_RANGE:
    for bb_val in BB_PERIODS:
        for symbol, df_orig in data_cache.items():
            df = df_orig.copy()

            # Indicators
            df['SMA_Value'] = ta.sma(df['Close'], length=sma_val)
            bb = ta.bbands(df['Close'], length=bb_val, std=2)
            if bb is None: continue

            bbm_col = [c for c in bb.columns if c.startswith('BBM')][0]
            df['BB_Midpoint'] = bb[bbm_col]

            # Logic: Cross above SMA AND Below BB Midpoint
            df['Prev_Close'] = df['Close'].shift(1)
            df['Prev_SMA'] = df['SMA_Value'].shift(1)

            cond_cross = (df['Close'] > df['SMA_Value']) & (df['Prev_Close'] <= df['Prev_SMA'])
            cond_value = df['Close'] < df['BB_Midpoint']

            # Filter and Label
            trades = df[cond_cross & cond_value].copy()
            if not trades.empty:
                # Forward Returns
                trades['Ret_3D'] = df['Close'].pct_change(3).shift(-3)
                trades['Ret_5D'] = df['Close'].pct_change(5).shift(-5)
                trades['Ret_10D'] = df['Close'].pct_change(10).shift(-10)

                # Metadata
                trades['Symbol'] = symbol
                trades['SMA_Param'] = sma_val
                trades['BB_Param'] = bb_val

                # Selecting Audit Columns
                audit_cols = [
                    'Symbol', 'SMA_Param', 'BB_Param',
                    'Close', 'SMA_Value', 'BB_Midpoint',
                    'Ret_3D', 'Ret_5D', 'Ret_10D'
                ]
                all_trades_list.append(trades[audit_cols])

master_trade_log = pd.concat(all_trades_list)
master_trade_log = master_trade_log.reset_index() # Keep the Date column
print(f"Done! {len(master_trade_log)} total trade instances recorded.")

# VIEW SPECIFIC SYMBOL DETAIL (Example: NVDA)
display(master_trade_log[master_trade_log['Symbol'] == 'NVDA'].head(20))
# Out:
# Fetching fresh data...
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CRWV']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['IBIT']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['WOLF']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CRCL']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SNDK']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BMNR']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['NBIS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1638334800, endDate = 1672549200")')
# Generating Technical Audit Logs...
# Done! 23015 total trade instances recorded.
# Price       Date Symbol  SMA_Param  BB_Param      Close  SMA_Value  \
# 79    2021-12-15   NVDA          3        10  30.400108  28.929626
# 80    2021-12-21   NVDA          3        10  29.018787  28.143816
# 81    2022-01-11   NVDA          3        10  27.763216  27.434853
# 82    2022-01-28   NVDA          3        10  22.795845  22.475131
# 83    2022-02-24   NVDA          3        10  23.702084  23.130192
# 84    2022-03-09   NVDA          3        10  22.973419  21.921275
# 85    2022-04-04   NVDA          3        10  27.311760  27.071516
# 86    2022-04-13   NVDA          3        10  22.163847  21.836096
# 87    2022-04-18   NVDA          3        10  21.744591  21.709651
# 88    2022-04-25   NVDA          3        10  19.866909  19.831635
# 89    2022-04-28   NVDA          3        10  19.747118  18.961505
# 90    2022-05-02   NVDA          3        10  19.498560  19.253324
# 91    2022-05-13   NVDA          3        10  17.674778  16.807309
# 92    2022-05-25   NVDA          3        10  16.945072  16.646263
# 93    2022-06-15   NVDA          3        10  16.501347  15.978493
# 94    2022-06-21   NVDA          3        10  16.540285  15.990805
# 95    2022-07-05   NVDA          3        10  14.940771  14.858899
# 96    2022-07-13   NVDA          3        10  15.140462  15.109177
# 97    2022-08-10   NVDA          3        10  18.068905  17.631254
# 98    2022-08-24   NVDA          3        10  17.195267  17.119051
#
# Price  BB_Midpoint    Ret_3D    Ret_5D   Ret_10D
# 79       30.416480 -0.089957 -0.034768 -0.028661
# 80       29.188759  0.064316  0.031849 -0.050593
# 81       28.610079 -0.031456 -0.098860 -0.181364
# 82       23.822653  0.105166  0.064755  0.048555
# 83       24.424686 -0.011411 -0.001262 -0.045736
# 84       23.209069 -0.073173  0.064395  0.113844
# 85       27.344001 -0.115205 -0.198940 -0.188670
# 86       24.421563 -0.000225 -0.090979 -0.109039
# 87       23.327794 -0.073452 -0.086352 -0.103291
# 88       21.157128 -0.006030 -0.018541 -0.148327
# 89       20.294751 -0.009099 -0.047417 -0.182338
# 90       19.799525 -0.035274 -0.132238 -0.116163
# 91       18.172300 -0.043375 -0.057156  0.062408
# 92       16.980505  0.099970  0.154167  0.063435
# 93       17.741212  0.002360 -0.018273 -0.082774
# 94       16.838722  0.033804 -0.035253 -0.086684
# 95       15.906869  0.058407  0.007886  0.135525
# 96       15.217542  0.061791  0.174294  0.173173
# 97       18.290264  0.051666  0.013151 -0.048350
# 98       18.067510 -0.082511 -0.123563 -0.187426

# %%
# 1. Grouping by Symbol and Strategy Parameters
performance_summary = master_trade_log.groupby(['Symbol', 'SMA_Param', 'BB_Param']).agg(
    Trade_Count=('Ret_3D', 'count'),
    Wins_3D=('Ret_3D', lambda x: (x > 0).sum()),
    Wins_5D=('Ret_5D', lambda x: (x > 0).sum()),
    Wins_10D=('Ret_10D', lambda x: (x > 0).sum()),
    Avg_3D_Ret=('Ret_3D', 'mean'),
    Avg_5D_Ret=('Ret_5D', 'mean'),
    Avg_10D_Ret=('Ret_10D', 'mean')
).reset_index()

# 2. Calculate Win Rates
performance_summary['Win_Rate_3D'] = performance_summary['Wins_3D'] / performance_summary['Trade_Count']
performance_summary['Win_Rate_5D'] = performance_summary['Wins_5D'] / performance_summary['Trade_Count']
performance_summary['Win_Rate_10D'] = performance_summary['Wins_10D'] / performance_summary['Trade_Count']

# Define display columns for consistency
display_cols = [
    'Symbol', 'SMA_Param', 'BB_Param', 'Trade_Count',
    'Win_Rate_3D', 'Avg_3D_Ret',
    'Win_Rate_5D', 'Avg_5D_Ret',
    'Win_Rate_10D', 'Avg_10D_Ret'
]

# --- SECTION A: Best Parameter Set PER Symbol ---
# Sort by Symbol and Win Rate, then take the top 1 for each ticker
best_per_symbol = performance_summary.sort_values(
    ['Symbol', 'Win_Rate_10D', 'Avg_10D_Ret'],
    ascending=[True, False, False]
).groupby('Symbol').head(1)

print("--- [A] BEST PARAMETER COMBO PER SYMBOL (Top 25 by Win Rate) ---")
display(best_per_symbol[display_cols].sort_values('Win_Rate_10D', ascending=False).head(25).style.format({
    'Win_Rate_3D': '{:.1%}', 'Avg_3D_Ret': '{:.2%}',
    'Win_Rate_5D': '{:.1%}', 'Avg_5D_Ret': '{:.2%}',
    'Win_Rate_10D': '{:.1%}', 'Avg_10D_Ret': '{:.2%}'
}))
# Out:
# --- [A] BEST PARAMETER COMBO PER SYMBOL (Top 25 by Win Rate) ---
# <style type="text/css">
# </style>
# <table id="T_a2b6c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2b6c_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_a2b6c_level0_col1" class="col_heading level0 col1" >SMA_Param</th>
#       <th id="T_a2b6c_level0_col2" class="col_heading level0 col2" >BB_Param</th>
#       <th id="T_a2b6c_level0_col3" class="col_heading level0 col3" >Trade_Count</th>
#       <th id="T_a2b6c_level0_col4" class="col_heading level0 col4" >Win_Rate_3D</th>
#       <th id="T_a2b6c_level0_col5" class="col_heading level0 col5" >Avg_3D_Ret</th>
#       <th id="T_a2b6c_level0_col6" class="col_heading level0 col6" >Win_Rate_5D</th>
#       <th id="T_a2b6c_level0_col7" class="col_heading level0 col7" >Avg_5D_Ret</th>
#       <th id="T_a2b6c_level0_col8" class="col_heading level0 col8" >Win_Rate_10D</th>
#       <th id="T_a2b6c_level0_col9" class="col_heading level0 col9" >Avg_10D_Ret</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2b6c_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_a2b6c_row0_col0" class="data row0 col0" >AAPL</td>
#       <td id="T_a2b6c_row0_col1" class="data row0 col1" >13</td>
#       <td id="T_a2b6c_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_a2b6c_row0_col3" class="data row0 col3" >1</td>
#       <td id="T
</td>
#     </tr>
#     <tr>
#       <th id="T_a2b6c_level0_row5" class="row_heading level0 row5" >299</th>
#       <td id="T_a2b6c_row5_col0" class="data row5 col0" >ASTS</td>
#       <td id="T_a2b6c_row5_col1" class="data row5 col1" >18</td>
#       <td id="T_a2b6c_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_a2b6c_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_a2b6c_row5_col4" class="data row5 col4" >100.0%</td>
#       <td id="T_a2b6c_row5_col5" class="data row5 col5" >40.89%</td>
#       <td id="T_a2b6c_row5_col6" class="data row5 col6" >100.0%</td>
#       <td id="T_a2b6c_row5_col7" class="data row5 col7" >23.41%</td>
#       <td id="T_a2b6c_row5_col8" class="data row5 col8" >100.0%</td>
#       <td id="T_a2b6c_row5_col9" class="data row5 col9" >51.41%</td>
#     </tr>
#     <tr>
#       <th id="T_a2b6c_level0_row6" class="row_heading level0 row6" >332</th>
#       <td id="T_a2b6c_row6_col0" class="data row6 col0" >AVGO</td>
#       <td id="T_a2b6c_row6_col1" class="data row6 col1" >13</td>
#       <td id="T_a2b6c_row6_col2" class="data row6 col2" >10</td>
#       <td id="T_a2b6c_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_a2b6c_row6_col4" class="data row6 col4" >100.0%</td>
#       <td id="T_a2b6c_row6_col5" class="data row6 col5" >7.52%</td>
#       <td id="T_a2b6c_row6_col6" class="data row6 col6" >100.0%</td>
#       <td id="T_a2b6c_row6_col7" class="data row6 col7" >5.07%</td>
#       <td id="T_a2b6c_row6_col8" class="data row6 col8" >100.0%</td>
#       <td id="T_a2b6c_row6_col9" class="data row6 col9" >5.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a2b6c_level0_row7" class="row_heading level0 row7" >464</th>
#       <td id="T_a2b6c_row7_col0" class="data row7 col0" >BE</td>
#       <td id="T_a2b6c_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_a2b6c_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_a2b6c_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_a2b6c_row7_col4" class="data row7 col4" >100.0%</td>
#       <td id="T_a2b6c_row7_col5" class="data row7 col5" >6.55%</td>
#       <td id="T_a2b6c_row7_col6" class="data row7 col6" >100.0%</td>
#       <td id="T_a2b6c_row7_col7" class="data row7 col7" >11.43%</td>
#       <td id="T_a2b6c_row7_col8" class="data row7 col8" >100.0%</td>
#       <td id="T_a2b6c_row7_col9" class="data row7 col9" >18.22%</td>
#     </tr>
#     <tr>
#       <th id="T_a2b6c_level0_row8" class="row_heading level0 row8" >743</th>
#       <td id="T_a2b6c_row8_col0" class="data row8 col0" >GLD</td>
#       <td id="T_a2b6c_row8_col1" class="data row8 col1" >19</td>
#       <td id="T_a2b6c_row8_col2" class="data row8 col2" >20</td>
#       <td id="T_a2b6c_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_a2b6c_row8_col4" class="data row8 col4" >100.0%</td>
#       <td id="T_a2b6c_row8_col5" class="data row8 col5" >2.08%</td>
#       <td id="T_a2b6c_row8_col6" class="data row8 col6" >100.0%</td>
#       <td id="T_a2b6c_row8_col7" class="data row8 col7" >1.72%</td>
#       <td id="T_a2b6c_row8_col8" class="data row8 col8" >100.0%</td>
#       <td id="T_a2b6c_row8_col9" class="data row8 col9" >3.16%</td>
#     </tr>
#     <tr>
#       <th id="T_a2b6c_level0_row9" class="row_heading level0 row9" >675</th>

# %%
# 1. Global Aggregation: Using the Raw Trade Log
# This avoids 'average of averages' for both Win Rates AND Returns.
global_strategy_raw = master_trade_log.groupby(['SMA_Param', 'BB_Param']).agg({
    'Symbol': 'count',      # Total Trade Count
    'Ret_3D': [
        ('Wins', lambda x: (x > 0).sum()),
        ('Avg_Ret', 'mean')
    ],
    'Ret_5D': [
        ('Wins', lambda x: (x > 0).sum()),
        ('Avg_Ret', 'mean')
    ],
    'Ret_10D': [
        ('Wins', lambda x: (x > 0).sum()),
        ('Avg_Ret', 'mean')
    ]
})

# 2. Flatten Multi-index columns for cleaner access
global_strategy_raw.columns = [
    'Total_Trades',
    'Wins_3D', 'Avg_3D_Ret',
    'Wins_5D', 'Avg_5D_Ret',
    'Wins_10D', 'Avg_10D_Ret'
]
global_strategy_raw = global_strategy_raw.reset_index()

# 3. Recalculate Global Win Rates from raw counts
global_strategy_raw['Win_Rate_3D'] = global_strategy_raw['Wins_3D'] / global_strategy_raw['Total_Trades']
global_strategy_raw['Win_Rate_5D'] = global_strategy_raw['Wins_5D'] / global_strategy_raw['Total_Trades']
global_strategy_raw['Win_Rate_10D'] = global_strategy_raw['Wins_10D'] / global_strategy_raw['Total_Trades']

# 4. Final Formatting & Sorting
final_cols = [
    'SMA_Param', 'BB_Param', 'Total_Trades',
    'Win_Rate_3D', 'Avg_3D_Ret',
    'Win_Rate_5D', 'Avg_5D_Ret',
    'Win_Rate_10D', 'Avg_10D_Ret'
]

global_strategy_raw = global_strategy_raw[final_cols].sort_values(by='Win_Rate_10D', ascending=False)

print("--- GLOBAL PARAMETER LEADERS (Recalculated from Raw Trade Data) ---")
display(global_strategy_raw.head(10).style.format({
    'Win_Rate_3D': '{:.1%}', 'Avg_3D_Ret': '{:.2%}',
    'Win_Rate_5D': '{:.1%}', 'Avg_5D_Ret': '{:.2%}',
    'Win_Rate_10D': '{:.1%}', 'Avg_10D_Ret': '{:.2%}'
}))
# Out:
# --- GLOBAL PARAMETER LEADERS (Recalculated from Raw Trade Data) ---
# <style type="text/css">
# </style>
# <table id="T_69dc3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69dc3_level0_col0" class="col_heading level0 col0" >SMA_Param</th>
#       <th id="T_69dc3_level0_col1" class="col_heading level0 col1" >BB_Param</th>
#       <th id="T_69dc3_level0_col2" class="col_heading level0 col2" >Total_Trades</th>
#       <th id="T_69dc3_level0_col3" class="col_heading level0 col3" >Win_Rate_3D</th>
#       <th id="T_69dc3_level0_col4" class="col_heading level0 col4" >Avg_3D_Ret</th>
#       <th id="T_69dc3_level0_col5" class="col_heading level0 col5" >Win_Rate_5D</th>
#       <th id="T_69dc3_level0_col6" class="col_heading level0 col6" >Avg_5D_Ret</th>
#       <th id="T_69dc3_level0_col7" class="col_heading level0 col7" >Win_Rate_10D</th>
#       <th id="T_69dc3_level0_col8" class="col_heading level0 col8" >Avg_10D_Ret</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69dc3_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_69dc3_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_69dc3_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_69dc3_row0_col2" class="data row0 col2" >48</td>
#       <td id="T_69dc3_row0_col3" class="data row0 col3" >45.8%</td>
#       <td id="T_69dc3_row0_col4" class="data row0 col4" >0.05%</td>
#       <td id="T_69dc3_row0_col5" class="data row0 col5" >60.4%</td>
#       <td id="T_69dc3_row0_col6" class="data row0 col6" >1.83%</td>
#       <td id="T_69dc3_row0_col7" class="data row0 col7" >66.7%</td>
#       <td id="T_69dc3_row0_col8" class="data row0 col8" >1.23%</td>
#     </tr>
#     <tr>
#       <th id="T_69dc3_level0_row1" class="row_heading level0 row1" >32</th>
#       <td id="T
</td>
#     </tr>
#     <tr>
#       <th id="T_69dc3_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_69dc3_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_69dc3_row7_col1" class="data row7 col1" >30</td>
#       <td id="T_69dc3_row7_col2" class="data row7 col2" >479</td>
#       <td id="T_69dc3_row7_col3" class="data row7 col3" >45.9%</td>
#       <td id="T_69dc3_row7_col4" class="data row7 col4" >-0.85%</td>
#       <td id="T_69dc3_row7_col5" class="data row7 col5" >44.3%</td>
#       <td id="T_69dc3_row7_col6" class="data row7 col6" >-1.40%</td>
#       <td id="T_69dc3_row7_col7" class="data row7 col7" >43.6%</td>
#       <td id="T_69dc3_row7_col8" class="data row7 col8" >-1.56%</td>
#     </tr>
#     <tr>
#       <th id="T_69dc3_level0_row8" class="row_heading level0 row8" >34</th>
#       <td id="T_69dc3_row8_col0" class="data row8 col0" >14</td>
#       <td id="T_69dc3_row8_col1" class="data row8 col1" >30</td>
#       <td id="T_69dc3_row8_col2" class="data row8 col2" >423</td>
#       <td id="T_69dc3_row8_col3" class="data row8 col3" >48.0%</td>
#       <td id="T_69dc3_row8_col4" class="data row8 col4" >-0.64%</td>
#       <td id="T_69dc3_row8_col5" class="data row8 col5" >44.2%</td>
#       <td id="T_69dc3_row8_col6" class="data row8 col6" >-1.32%</td>
#       <td id="T_69dc3_row8_col7" class="data row8 col7" >43.5%</td>
#       <td id="T_69dc3_row8_col8" class="data row8 col8" >-1.67%</td>
#     </tr>
#     <tr>
#       <th id="T_69dc3_level0_row9" class="row_heading level0 row9" >31</th>
#       <td id="T_69dc3_row9_col0" class="data row9 col0" >13</td>
#       <td id="T_69dc3_row9_col1" class="data row9 col1" >30</td>
#       <td id="T_69dc3_row9_col2" class="data row9 col2" >449</td>
#       <td id="T_69dc3_row9_col3" class="data row9 col3" >45.4%</td>
#       <td id="T_69dc3_row9_col4" class="data row9 col4" >-0.94%</td>
#       <td id="T_69dc3_row9_col5" class="data row9 col5" >44.3%</td>
#       <td id="T_69dc3_row9_col6" class="data row9 col6" >-1.61%</td>
#       <td id="T_69dc3_row9_col7" class="data row9 col7" >42.8%</td>
#       <td id="T_69dc3_row9_col8" class="data row9 col8" >-1.93%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- Symbol Drill-Down Section ---
target_symbol = "NVDA"  # Change this to any symbol from your list

print(f"--- Top 10 Parameter Combinations for {target_symbol} (Sorted by Avg_10D_Ret) ---")

# Filter the performance_summary we created above
symbol_drill_down = performance_summary[performance_summary['Symbol'] == target_symbol]

# Display the results
display(symbol_drill_down[display_cols].sort_values('Avg_10D_Ret', ascending=False).head(10).style.format({
    'Win_Rate_3D': '{:.1%}', 'Avg_3D_Ret': '{:.2%}',
    'Win_Rate_5D': '{:.1%}', 'Avg_5D_Ret': '{:.2%}',
    'Win_Rate_10D': '{:.1%}', 'Avg_10D_Ret': '{:.2%}'
}))
# Out:
# --- Top 10 Parameter Combinations for NVDA (Sorted by Avg_10D_Ret) ---
# <style type="text/css">
# </style>
# <table id="T_989bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_989bb_level0_col0" class="col_heading level0 col0" >Symbol</th>
#       <th id="T_989bb_level0_col1" class="col_heading level0 col1" >SMA_Param</th>
#       <th id="T_989bb_level0_col2" class="col_heading level0 col2" >BB_Param</th>
#       <th id="T_989bb_level0_col3" class="col_heading level0 col3" >Trade_Count</th>
#       <th id="T_989bb_level0_col4" class="col_heading level0 col4" >Win_Rate_3D</th>
#       <th id="T_989bb_level0_col5" class="col_heading level0 col5" >Avg_3D_Ret</th>
#       <th id="T_989bb_level0_col6" class="col_heading level0 col6" >Win_Rate_5D</th>
#       <th id="T_989bb_level0_col7" class="col_heading level0 col7" >Avg_5D_Ret</th>
#       <th id="T_989bb_level0_col8" class="col_heading level0 col8" >Win_Rate_10D</th>
#       <th id="T_989bb_level0_col9" class="col_heading level0 col9" >Avg_10D_Ret</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_989bb_level0_row0" class="row_heading level0 row0" >1570</th>
#       <td id="T_989bb_row0_col0" class="data row0 col0" >NVDA</td>
#       <td id="T_989bb_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_989bb_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_989bb_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_989bb_row0_col4" class="data row0 col4" >37.5%</td>
#       <td id="T_989bb_row0_col5" class="data row0 col5" >-0.76%</td>
#       <td id="T_989bb_row0_col6" class="data row0 col6" >50.0%</td>
#       <td id="T_989bb_row0_col7" class="data row0 col7" >-0.39%</td>
#       <td id="T_989bb_row0_col8" class="data row0 col8" >62.5%</td>
#       <td id="T_989bb_row0_col9" class="data row0 col9" >4.10%</td>
#     </tr>
#     <tr>
#       <th id="T_989bb_level0_row1" class="row_heading level0 row1" >1582</th>
#       <td id="T_989bb_row1_col0" class="data row1 col0" >NVDA</td>
#       <td id="T_989bb_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_989bb_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_989bb_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_989bb_row1_col4" class="data row1 col4" >60.0%</td>
#       <td id="T_989bb_row1_col5" class="data row1 col5" >3.01%</td>
#       <td id="T_989bb_row1_col6" class="data row1 col6" >60.0%</td>
#       <td id="T_989bb_row1_col7" class="data row1 col7" >1.91%</td>
#       <td id="T_989bb_row1_col8" class="data row1 col8" >60.0%</td>
#       <td id="T_989bb_row1_col9" class="data row1 col9" >4.07%</td>
#     </tr>
#     <tr>
#       <th id="T_989bb_level0_row2" class="row_heading level0 row2" >1576</th>
#       <td id="T_989bb_row2_col0" class="data row2 col0" >NVDA</td>
#       <td id="T_989bb_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_989bb_row2_col2" class="data row2 col2" >20</td>
#       <td id="T_989bb_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_989bb_row2_col4" class="data row2 col4" >42.9%</td>
#       <td id="T_989bb_row2_col5" class="data row2 col5" >0.23%</td>
#       <td id="T_989bb_row2_col6" class="data row2 col6" >42.9%</td>
#       <td id="T_989bb_row2_col7" class="data row2 col7" >-1.80%</td>
#       <td id="T_989bb_row2_col8" class="data row2 col8" >57.1%</td>
#       <td id="T_989bb_row2_col9" class="data row2 col9" >3.59%</td>
#     </tr>
#     <tr>
#       <th id="T_989bb_level0_
</td>
#     </tr>
#     <tr>
#       <th id="T_989bb_level0_row7" class="row_heading level0 row7" >1562</th>
#       <td id="T_989bb_row7_col0" class="data row7 col0" >NVDA</td>
#       <td id="T_989bb_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_989bb_row7_col2" class="data row7 col2" >20</td>
#       <td id="T_989bb_row7_col3" class="data row7 col3" >12</td>
#       <td id="T_989bb_row7_col4" class="data row7 col4" >33.3%</td>
#       <td id="T_989bb_row7_col5" class="data row7 col5" >-0.83%</td>
#       <td id="T_989bb_row7_col6" class="data row7 col6" >33.3%</td>
#       <td id="T_989bb_row7_col7" class="data row7 col7" >-1.56%</td>
#       <td id="T_989bb_row7_col8" class="data row7 col8" >50.0%</td>
#       <td id="T_989bb_row7_col9" class="data row7 col9" >2.47%</td>
#     </tr>
#     <tr>
#       <th id="T_989bb_level0_row8" class="row_heading level0 row8" >1560</th>
#       <td id="T_989bb_row8_col0" class="data row8 col0" >NVDA</td>
#       <td id="T_989bb_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_989bb_row8_col2" class="data row8 col2" >30</td>
#       <td id="T_989bb_row8_col3" class="data row8 col3" >11</td>
#       <td id="T_989bb_row8_col4" class="data row8 col4" >54.5%</td>
#       <td id="T_989bb_row8_col5" class="data row8 col5" >1.06%</td>
#       <td id="T_989bb_row8_col6" class="data row8 col6" >45.5%</td>
#       <td id="T_989bb_row8_col7" class="data row8 col7" >-0.11%</td>
#       <td id="T_989bb_row8_col8" class="data row8 col8" >45.5%</td>
#       <td id="T_989bb_row8_col9" class="data row8 col9" >2.35%</td>
#     </tr>
#     <tr>
#       <th id="T_989bb_level0_row9" class="row_heading level0 row9" >1568</th>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Prepare the Aggregate Data (if not already done in Cell 2)
param_perf = master_trade_log.groupby(['SMA_Param', 'BB_Param']).agg({
    'Ret_3D': 'mean',
    'Ret_5D': 'mean',
    'Ret_10D': 'mean'
}).reset_index()

# 2. Define the horizons we want to visualize
horizons = [('3D', 'Ret_3D'), ('5D', 'Ret_5D'), ('10D', 'Ret_10D')]

print("--- PARAMETER SURFACE HEATMAPS (Average Returns) ---")

for label, col_name in horizons:
    # Pivot the data for the heatmap
    pivot_table = param_perf.pivot(index="SMA_Param", columns="BB_Param", values=col_name)

    # Create the visualization using Pandas Styler for a clean Colab output
    print(f"\n{label} Horizon Average Return:")
    display(pivot_table.style.background_gradient(cmap='RdYlGn', axis=None)
            .format("{:.2%}")
            .set_caption(f"Average {label} Return by SMA and BB Period"))

# Optional: If you prefer a more "visual" graphical heatmap using Seaborn:
# plt.figure(figsize=(10, 6))
# sns.heatmap(pivot_table, annot=True, fmt=".2%", cmap="RdYlGn")
# plt.title("10D Return Surface")
# plt.show()
# Out:
# --- PARAMETER SURFACE HEATMAPS (Average Returns) ---
#
# 3D Horizon Average Return:
# <style type="text/css">
# #T_49502_row0_col0 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_49502_row0_col1, #T_49502_row12_col0 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_49502_row0_col2 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_49502_row1_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_49502_row1_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_49502_row1_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_49502_row2_col0 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_49502_row2_col1, #T_49502_row10_col2, #T_49502_row14_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_49502_row2_col2, #T_49502_row3_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_49502_row3_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_49502_row3_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_49502_row4_col0, #T_49502_row16_col1 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_49502_row4_col1 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_49502_row4_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_49502_row5_col0, #T_49502_row9_col2 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T
</td>
#     </tr>
#     <tr>
#       <th id="T_49502_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_49502_row9_col0" class="data row9 col0" >0.05%</td>
#       <td id="T_49502_row9_col1" class="data row9 col1" >-0.98%</td>
#       <td id="T_49502_row9_col2" class="data row9 col2" >-0.85%</td>
#     </tr>
#     <tr>
#       <th id="T_49502_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_49502_row10_col0" class="data row10 col0" >0.85%</td>
#       <td id="T_49502_row10_col1" class="data row10 col1" >-1.16%</td>
#       <td id="T_49502_row10_col2" class="data row10 col2" >-0.94%</td>
#     </tr>
#     <tr>
#       <th id="T_49502_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_49502_row11_col0" class="data row11 col0" >1.35%</td>
#       <td id="T_49502_row11_col1" class="data row11 col1" >-0.76%</td>
#       <td id="T_49502_row11_col2" class="data row11 col2" >-0.64%</td>
#     </tr>
#     <tr>
#       <th id="T_49502_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_49502_row12_col0" class="data row12 col0" >-0.31%</td>
#       <td id="T_49502_row12_col1" class="data row12 col1" >-0.55%</td>
#       <td id="T_49502_row12_col2" class="data row12 col2" >-0.67%</td>
#     </tr>
#     <tr>
#       <th id="T_49502_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_49502_row13_col0" class="data row13 col0" >-0.69%</td>
#       <td id="T_49502_row13_col1" class="data row13 col1" >-0.51%</td>
#       <td id="T_49502_
# 5D Horizon Average Return:
# <style type="text/css">
# #T_f8ab0_row0_col0 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_f8ab0_row0_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_f8ab0_row0_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_f8ab0_row1_col0 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_f8ab0_row1_col1, #T_f8ab0_row13_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_f8ab0_row1_col2, #T_f8ab0_row16_col0 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_f8ab0_row2_col0, #T_f8ab0_row8_col2, #T_f8ab0_row10_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_f8ab0_row2_col1 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_f8ab0_row2_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_f8ab0_row3_col0, #T_f8ab0_row16_col1 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_f8ab0_row3_col1 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_f8ab0_row3_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_f8ab0_row4_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_f8ab0_row4_col1 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_f8ab0_row4_col2, #T_f8ab0_row5_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_f8ab0_row5_col0 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_f8ab0_row5_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_f8ab0_row6_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f8ab0_row6_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_f8ab0_row6_col2 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_f8ab0_row7_col0, #T_f8ab0_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f8ab0_row7_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_f8ab0_row7_col2, #T_f8ab0_row14_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_f8ab0_row8_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f8ab0_row8_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_f8ab0_row9_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_f8ab0_row9_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_f8ab0_row9_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_f8ab0_row10_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_f8ab0_row10_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_f8ab0_row11_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_f8ab0_row11_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_f8ab0_row11_col2 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_f8ab0_row12_col0 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_f8ab0_row12_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_f8ab0_row12_col2 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_f8ab0_row13_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_f8ab0_row13_col1, #T_f8ab0_row15_col1 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_f8ab0_row14_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_f8ab0_row14_col2 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_f8ab0_row15_col0 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_f8ab0_row15_col2 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_f8ab0_row16_col2 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_f8ab0_row17_col0 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_f8ab0_row17_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# </style>
# <table id="T_f8ab0" class="dataframe">
#   <caption>Average 5D Return by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_f8ab0_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_f8ab0_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_f8ab0_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8ab0_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_f8ab0_row0_col0" class="data row0 col0" >-1.01%</td>
#       <td id="T_f8ab0_row0_col1" class="data row0 col1" >-1.05%</td>
#       <td id="T_f8ab0_row0_col2" class="data row0 col2" >-0.94%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_f8ab0_row1_col0" class="data row1 col0" >-1.19%</td>
#       <td id="T_f8ab0_row1_col1" class="data row1 col1" >-1.20%</td>
#       <td id="T_f8ab0_row1_col2" class="data row1 col2" >-0.96%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_f8ab0_row2_col0" class="data row2 col0" >-1.62%</td>
#       <td id="T_f8ab0_row2_col1" class="data row2 col1" >-1.67%</td>
#       <td id="T_f8ab0_row2_col2" class="data row2 col2" >-1.22%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_f8ab0_row3_col0" class="data row3 col0" >-2.11%</td>
#       <td id="T_f8ab0_row3_col1" class="data row3 col1" >-1.98%</td>
#       <td id="T_f8ab0_row3_col2" class="data row3 col2" >-1.42%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_f8ab0_row4_col0" class="data row4 col0" >-2.19%</td>
#       <td id="T_f8ab0_row4_col1" class="data row4 col1" >-2.17%</td>
#       <td id="T_f8ab0_row4_col2" class="data row4 col2" >-1.71%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_f8ab0_row5_col0" class="data row5 col0" >-2.52%</td>
#       <td id="T_f8ab0_row5_col1" class="data row5 col1" >-2.38%</td>
#       <td id="T_f8ab0_row5_col2" class="data row5 col2" >-1.70%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_f8ab0_row6_col0" class="data row6 col0" >-2.76%</td>
#       <td id="T_f8ab0_row6_col1" class="data row6 col1" >-2.35%</td>
#       <td id="T_f8ab0_row6_col2" class="data row6 col2" >-1.87%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_f8ab0_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_f8ab0_row7_col1" class="data row7 col1" >-2.13%</td>
#       <td id="T_f8ab0_row7_col2" class="data row7 col2" >-1.76%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_f8ab0_row8_col0" class="data row8 col0" >1.86%</td>
#       <td id="T_f8ab0_row8_col1" class="data row8 col1" >-1.91%</td>
#       <td id="T_f8ab0_row8_col2" class="data row8 col2" >-1.62%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_f8ab0_row9_col0" class="data row9 col0" >1.83%</td>
#       <td id="T_f8ab0_row9_col1" class="data row9 col1" >-1.69%</td>
#       <td id="T_f8ab0_row9_col2" class="data row9 col2" >-1.40%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_f8ab0_row10_col0" class="data row10 col0" >1.47%</td>
#       <td id="T_f8ab0_row10_col1" class="data row10 col1" >-2.03%</td>
#       <td id="T_f8ab0_row10_col2" class="data row10 col2" >-1.61%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_f8ab0_row11_col0" class="data row11 col0" >1.47%</td>
#       <td id="T_f8ab0_row11_col1" class="data row11 col1" >-1.72%</td>
#       <td id="T_f8ab0_row11_col2" class="data row11 col2" >-1.32%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_f8ab0_row12_col0" class="data row12 col0" >-0.04%</td>
#       <td id="T_f8ab0_row12_col1" class="data row12 col1" >-1.55%</td>
#       <td id="T_f8ab0_row12_col2" class="data row12 col2" >-1.28%</td>
#     </tr>
#     <tr>
#       <th id="T_f8ab0_level0_row13" class=
# 10D Horizon Average Return:
# <style type="text/css">
# #T_23897_row0_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_23897_row0_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_23897_row0_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_23897_row1_col0 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_23897_row1_col1, #T_23897_row8_col1 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_23897_row1_col2 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_23897_row2_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_23897_row2_col1 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_23897_row2_col2 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_23897_row3_col0 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_23897_row3_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_23897_row3_col2, #T_23897_row4_col2, #T_23897_row7_col2, #T_23897_row14_col2 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_23897_row4_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_23897_row4_col1, #T_23897_row6_col1, #T_23897_row10_col1 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_23897_row5_col0, #T_23897_row15_col2 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_23897_row5_col1 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_23897_row5_col2, #T_23897_row11_col2 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_23897_row6_col0 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_23897_row6_col2, #T_23897_row8_col2, #T_23897_row16_col2 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_23897_row7_col0, #T_23897_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_23897_row7_col1 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_23897_row8_col0 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_23897_row9_col0 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_23897_row9_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_23897_row9_col2 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_23897_row10_col0 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_23897_row10_col2 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_23897_row11_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_23897_row11_col1, #T_23897_row16_col1 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_23897_row12_col0 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_23897_row12_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_23897_row12_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_23897_row13_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_23897_row13_col1 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T
level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_23897_row13_col0" class="data row13 col0" >1.13%</td>
#       <td id="T_23897_row13_col1" class="da

# %%
# 1. Prepare the Win Rate Aggregate Data
# We calculate the mean of the boolean (Return > 0) to get the percentage of wins
win_rate_perf = master_trade_log.groupby(['SMA_Param', 'BB_Param']).agg({
    'Ret_3D': lambda x: (x > 0).mean(),
    'Ret_5D': lambda x: (x > 0).mean(),
    'Ret_10D': lambda x: (x > 0).mean()
}).reset_index()

# 2. Define the horizons for visualization
horizons = [('3-Day', 'Ret_3D'), ('5-Day', 'Ret_5D'), ('10-Day', 'Ret_10D')]

print("--- PARAMETER SURFACE HEATMAPS (Win Rate %) ---")
print("Focus: Probability of a positive return across the portfolio.")

for label, col_name in horizons:
    # Pivot the data for the heatmap
    pivot_win_rate = win_rate_perf.pivot(index="SMA_Param", columns="BB_Param", values=col_name)

    print(f"\n{label} Win Rate Surface:")
    # Using a 0.5 (50%) midpoint for the gradient helps highlight 'Edge' vs 'Coin Flip'
    display(pivot_win_rate.style.background_gradient(cmap='RdYlGn', vmin=0.45, vmax=0.65, axis=None)
            .format("{:.1%}")
            .set_caption(f"{label} Win Rate by SMA and BB Period"))
# Out:
# --- PARAMETER SURFACE HEATMAPS (Win Rate %) ---
# Focus: Probability of a positive return across the portfolio.
#
# 3-Day Win Rate Surface:
# <style type="text/css">
# #T_a8437_row0_col0, #T_a8437_row1_col0, #T_a8437_row2_col0, #T_a8437_row2_col1, #T_a8437_row2_col2, #T_a8437_row3_col0, #T_a8437_row3_col1, #T_a8437_row3_col2, #T_a8437_row4_col0, #T_a8437_row4_col1, #T_a8437_row5_col0, #T_a8437_row5_col1, #T_a8437_row6_col0, #T_a8437_row6_col1, #T_a8437_row7_col1, #T_a8437_row8_col1, #T_a8437_row9_col1, #T_a8437_row10_col1, #T_a8437_row12_col0, #T_a8437_row12_col1, #T_a8437_row13_col0, #T_a8437_row14_col0, #T_a8437_row14_col1, #T_a8437_row15_col0, #T_a8437_row16_col0, #T_a8437_row16_col1, #T_a8437_row17_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a8437_row0_col1 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_a8437_row0_col2, #T_a8437_row15_col2 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_a8437_row1_col1, #T_a8437_row9_col2 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_a8437_row1_col2 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_a8437_row4_col2, #T_a8437_row11_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_a8437_row5_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_a8437_row6_col2, #T_a8437_row15_col1 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_a8437_row7_col0, #T_a8437_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a8437_row7_col2 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_a8437_row8_col0 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T
0%</td>
#     </tr>
#     <tr>
#       <th id="T_a8437_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_a8437_row12_col0" class="data row12 col0" >41.1%</td>
#       <td id="T_a8437_row12_col1" class="data row12 col1" >45.0%</td>
#       <td id="T_a8437_row12_col2" class="data row12 col2" >47.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a8437_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_a8437_row13_col0" class="data row13 col0" >37.3%</td>
#       <td id="T_a8437_row13_col1" class="data row13 col1" >45.9%</td>
#       <td id="T_a8437_row13_col2" class="data row13 col2" >48.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a8437_level0_row14" class="row_heading level0 row14" >17</th>
#       <td id="T_a8437_row14_col0" class="data row14 col0" >30.9%</td>
#       <td id="T_a8437_row14_col1" class="data row14 col1" >44.3%</td>
#       <td id="T_a8437_row14_col2" class="data row14 col2" >47.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a8437_level0_row15" class="row_heading level0 row15" >18</th>
#       <td id="T_a8437_row15_col0" class="data row15 col0" >32.9%</td>
#       <td id="T_a8437_row15_col1" class="data row15 col1" >46.2%</td>
#       <td id="T_a8437_row15_col2" class="data row15 col2" >47.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a8437_level0_row16" class="row_heading level0 row16" >19</th>
#       <td id="T_a8437_row16_col0" class="data row16 col0" >36.6%</td>
#       <td id="T_a8437_row16_col1" class="data row16 col1" >44.6%</td>
#       <td id="T_a8437_row16_col2" class="data row16 col2" >47.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a8437_level0_row17" class="row_heading level0 row17" >20</th>
#       <td id="T_a8437_r
# 5-Day Win Rate Surface:
# <style type="text/css">
# #T_83eda_row0_col0, #T_83eda_row0_col1, #T_83eda_row0_col2, #T_83eda_row1_col0, #T_83eda_row1_col1, #T_83eda_row2_col0, #T_83eda_row2_col1, #T_83eda_row2_col2, #T_83eda_row3_col0, #T_83eda_row3_col1, #T_83eda_row3_col2, #T_83eda_row4_col0, #T_83eda_row4_col1, #T_83eda_row4_col2, #T_83eda_row5_col0, #T_83eda_row5_col1, #T_83eda_row5_col2, #T_83eda_row6_col0, #T_83eda_row6_col1, #T_83eda_row6_col2, #T_83eda_row7_col1, #T_83eda_row7_col2, #T_83eda_row8_col1, #T_83eda_row8_col2, #T_83eda_row9_col1, #T_83eda_row9_col2, #T_83eda_row10_col1, #T_83eda_row10_col2, #T_83eda_row11_col1, #T_83eda_row11_col2, #T_83eda_row12_col1, #T_83eda_row13_col0, #T_83eda_row13_col1, #T_83eda_row14_col0, #T_83eda_row14_col1, #T_83eda_row15_col0, #T_83eda_row15_col1, #T_83eda_row16_col0, #T_83eda_row17_col0, #T_83eda_row17_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_83eda_row1_col2 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_83eda_row7_col0, #T_83eda_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_83eda_row8_col0 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_83eda_row9_col0 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_83eda_row10_col0 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_83eda_row11_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_83eda_row12_col0 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_83eda_row12_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_83eda_row13_col2 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_83eda_row14_col2 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_83eda_row15_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_83eda_row16_col1 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_83eda_row16_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83eda" class="dataframe">
#   <caption>5-Day Win Rate by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_83eda_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_83eda_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_83eda_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83eda_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_83eda_row0_col0" class="data row0 col0" >42.3%</td>
#       <td id="T_83eda_row0_col1" class="data row0 col1" >42.4%</td>
#       <td id="T_83eda_row0_col2" class="data row0 col2" >44.1%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_83eda_row1_col0" class="data row1 col0" >43.5%</td>
#       <td id="T_83eda_row1_col1" class="data row1 col1" >43.5%</td>
#       <td id="T_83eda_row1_col2" class="data row1 col2" >45.9%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_83eda_row2_col0" class="data row2 col0" >39.4%</td>
#       <td id="T_83eda_row2_col1" class="data row2 col1" >39.9%</td>
#       <td id="T_83eda_row2_col2" class="data row2 col2" >43.4%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_83eda_row3_col0" class="data row3 col0" >38.7%</td>
#       <td id="T_83eda_row3_col1" class="data row3 col1" >39.9%</td>
#       <td id="T_83eda_row3_col2" class="data row3 col2" >43.6%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_83eda_row4_col0" class="data row4 col0" >38.5%</td>
#       <td id="T_83eda_row4_col1" class="data row4 col1" >40.0%</td>
#       <td id="T_83eda_row4_col2" class="data row4 col2" >42.2%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_83eda_row5_col0" class="data row5 col0" >38.7%</td>
#       <td id="T_83eda_row5_col1" class="data row5 col1" >40.3%</td>
#       <td id="T_83eda_row5_col2" class="data row5 col2" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_83eda_row6_col0" class="data row6 col0" >37.2%</td>
#       <td id="T_83eda_row6_col1" class="data row6 col1" >39.7%</td>
#       <td id="T_83eda_row6_col2" class="data row6 col2" >42.0%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_83eda_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_83eda_row7_col1" class="data row7 col1" >39.7%</td>
#       <td id="T_83eda_row7_col2" class="data row7 col2" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_83eda_row8_col0" class="data row8 col0" >60.0%</td>
#       <td id="T_83eda_row8_col1" class="data row8 col1" >41.1%</td>
#       <td id="T_83eda_row8_col2" class="data row8 col2" >42.7%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_83eda_row9_col0" class="data row9 col0" >60.4%</td>
#       <td id="T_83eda_row9_col1" class="data row9 col1" >42.3%</td>
#       <td id="T_83eda_row9_col2" class="data row9 col2" >44.3%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_83eda_row10_col0" class="data row10 col0" >60.3%</td>
#       <td id="T_83eda_row10_col1" class="data row10 col1" >42.2%</td>
#       <td id="T_83eda_row10_col2" class="data row10 col2" >44.3%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_83eda_row11_col0" class="data row11 col0" >55.2%</td>
#       <td id="T_83eda_row11_col1" class="data row11 col1" >41.3%</td>
#       <td id="T_83eda_row11_col2" class="data row11 col2" >44.2%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_83eda_row12_col0" class="data row12 col0" >47.9%</td>
#       <td id="T_83eda_row12_col1" class="data row12 col1" >43.1%</td>
#       <td id="T_83eda_row12_col2" class="data row12 col2" >45.3%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_83eda_row13_col0" class="data row13 col0" >44.0%</td>
#       <td id="T_83eda_row13_col1" class="data row13 col1" >44.1%</td>
#       <td id="T_83eda_row13_col2" class="data row13 col2" >46.2%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row14" class="row_heading level0 row14" >17</th>
#       <td id="T_83eda_row14_col0" class="data row14 col0" >42.0%</td>
#       <td id="T_83eda_row14_col1" class="data row14 col1" >44.9%</td>
#       <td id="T_83eda_row14_col2" class="data row14 col2" >46.5%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row15" class="row_heading level0 row15" >18</th>
#       <td id="T_83eda_row15_col0" class="data row15 col0" >39.2%</td>
#       <td id="T_83eda_row15_col1" class="data row15 col1" >44.5%</td>
#       <td id="T_83eda_row15_col2" class="data row15 col2" >46.3%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row16" class="row_heading level0 row16" >19</th>
#       <td id="T_83eda_row16_col0" class="data row16 col0" >39.0%</td>
#       <td id="T_83eda_row16_col1" class="data row16 col1" >48.2%</td>
#       <td id="T_83eda_row16_col2" class="data row16 col2" >45.5%</td>
#     </tr>
#     <tr>
#       <th id="T_83eda_level0_row17" class="row_heading level0 row17" >20</th>
#       <td id="T_83eda_row17_col0" class="data row17 col0" >35.9%</td>
#       <td id="T_83eda_row17_col1" class="data row17 col1" >nan%</td>
#       <td id="T_83eda_row17_col2" class="data row17 col2" >44.3%</td>
#     </tr>
#   </tbody>
# </table>
# 10-Day Win Rate Surface:
# <style type="text/css">
# #T_4d90e_row0_col0, #T_4d90e_row0_col1, #T_4d90e_row0_col2, #T_4d90e_row1_col0, #T_4d90e_row1_col1, #T_4d90e_row1_col2, #T_4d90e_row2_col0, #T_4d90e_row2_col1, #T_4d90e_row2_col2, #T_4d90e_row3_col0, #T_4d90e_row3_col1, #T_4d90e_row3_col2, #T_4d90e_row4_col0, #T_4d90e_row4_col1, #T_4d90e_row4_col2, #T_4d90e_row5_col0, #T_4d90e_row5_col1, #T_4d90e_row5_col2, #T_4d90e_row6_col0, #T_4d90e_row6_col1, #T_4d90e_row6_col2, #T_4d90e_row7_col1, #T_4d90e_row7_col2, #T_4d90e_row8_col1, #T_4d90e_row8_col2, #T_4d90e_row9_col1, #T_4d90e_row9_col2, #T_4d90e_row10_col1, #T_4d90e_row10_col2, #T_4d90e_row11_col1, #T_4d90e_row11_col2, #T_4d90e_row12_col1, #T_4d90e_row12_col2, #T_4d90e_row13_col1, #T_4d90e_row13_col2, #T_4d90e_row14_col0, #T_4d90e_row14_col1, #T_4d90e_row14_col2, #T_4d90e_row15_col0, #T_4d90e_row15_col1, #T_4d90e_row15_col2, #T_4d90e_row16_col0, #T_4d90e_row16_col1, #T_4d90e_row16_col2, #T_4d90e_row17_col0, #T_4d90e_row17_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4d90e_row7_col0, #T_4d90e_row17_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4d90e_row8_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_4d90e_row9_col0, #T_4d90e_row11_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4d90e_row10_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_4d90e_row12_col0 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_4d90e_row13_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d90e" class="dataframe">
#   <caption>10-Day Win Rate by SMA and BB Period</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >BB_Param</th>
#       <th id="T_4d90e_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_4d90e_level0_col1" class="col_heading level0 col1" >20</th>
#       <th id="T_4d90e_level0_col2" class="col_heading level0 col2" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SMA_Param</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d90e_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_4d90e_row0_col0" class="data row0 col0" >39.2%</td>
#       <td id="T_4d90e_row0_col1" class="data row0 col1" >39.4%</td>
#       <td id="T_4d90e_row0_col2" class="data row0 col2" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_4d90e_row1_col0" class="data row1 col0" >37.3%</td>
#       <td id="T_4d90e_row1_col1" class="data row1 col1" >37.5%</td>
#       <td id="T_4d90e_row1_col2" class="data row1 col2" >40.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_4d90e_row2_col0" class="data row2 col0" >35.6%</td>
#       <td id="T_4d90e_row2_col1" class="data row2 col1" >36.3%</td>
#       <td id="T_4d90e_row2_col2" class="data row2 col2" >39.9%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_4d90e_row3_col0" class="data row3 col0" >35.0%</td>
#       <td id="T_4d90e_row3_col1" class="data row3 col1" >36.7%</td>
#       <td id="T_4d90e_row3_col2" class="data row3 col2" >40.4%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_4d90e_row4_col0" class="data row4 col0" >36.8%</td>
#       <td id="T_4d90e_row4_col1" class="data row4 col1" >37.6%</td>
#       <td id="T_4d90e_row4_col2" class="data row4 col2" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_4d90e_row5_col0" class="data row5 col0" >39.0%</td>
#       <td id="T_4d90e_row5_col1" class="data row5 col1" >38.2%</td>
#       <td id="T_4d90e_row5_col2" class="data row5 col2" >41.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_4d90e_row6_col0" class="data row6 col0" >39.4%</td>
#       <td id="T_4d90e_row6_col1" class="data row6 col1" >38.3%</td>
#       <td id="T_4d90e_row6_col2" class="data row6 col2" >41.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_4d90e_row7_col0" class="data row7 col0" >nan%</td>
#       <td id="T_4d90e_row7_col1" class="data row7 col1" >38.4%</td>
#       <td id="T_4d90e_row7_col2" class="data row7 col2" >41.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_4d90e_row8_col0" class="data row8 col0" >62.5%</td>
#       <td id="T_4d90e_row8_col1" class="data row8 col1" >41.6%</td>
#       <td id="T_4d90e_row8_col2" class="data row8 col2" >43.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_4d90e_row9_col0" class="data row9 col0" >66.7%</td>
#       <td id="T_4d90e_row9_col1" class="data row9 col1" >41.8%</td>
#       <td id="T_4d90e_row9_col2" class="data row9 col2" >43.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row10" class="row_heading level0 row10" >13</th>
#       <td id="T_4d90e_row10_col0" class="data row10 col0" >64.7%</td>
#       <td id="T_4d90e_row10_col1" class="data row10 col1" >41.3%</td>
#       <td id="T_4d90e_row10_col2" class="data row10 col2" >42.8%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_4d90e_row11_col0" class="data row11 col0" >65.7%</td>
#       <td id="T_4d90e_row11_col1" class="data row11 col1" >41.7%</td>
#       <td id="T_4d90e_row11_col2" class="data row11 col2" >43.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_4d90e_row12_col0" class="data row12 col0" >54.8%</td>
#       <td id="T_4d90e_row12_col1" class="data row12 col1" >38.7%</td>
#       <td id="T_4d90e_row12_col2" class="data row12 col2" >41.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_4d90e_row13_col0" class="data row13 col0" >45.3%</td>
#       <td id="T_4d90e_row13_col1" class="data row13 col1" >38.9%</td>
#       <td id="T_4d90e_row13_col2" class="data row13 col2" >41.1%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row14" class="row_heading level0 row14" >17</th>
#       <td id="T_4d90e_row14_col0" class="data row14 col0" >42.0%</td>
#       <td id="T_4d90e_row14_col1" class="data row14 col1" >37.8%</td>
#       <td id="T_4d90e_row14_col2" class="data row14 col2" >40.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row15" class="row_heading level0 row15" >18</th>
#       <td id="T_4d90e_row15_col0" class="data row15 col0" >41.8%</td>
#       <td id="T_4d90e_row15_col1" class="data row15 col1" >41.2%</td>
#       <td id="T_4d90e_row15_col2" class="data row15 col2" >41.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row16" class="row_heading level0 row16" >19</th>
#       <td id="T_4d90e_row16_col0" class="data row16 col0" >37.8%</td>
#       <td id="T_4d90e_row16_col1" class="data row16 col1" >37.5%</td>
#       <td id="T_4d90e_row16_col2" class="data row16 col2" >40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_4d90e_level0_row17" class="row_heading level0 row17" >20</th>
#       <td id="T_4d90e_row17_col0" class="data row17 col0" >38.5%</td>
#       <td id="T_4d90e_row17_col1" class="data row17 col1" >nan%</td>
#       <td id="T_4d90e_row17_col2" class="data row17 col2" >41.6%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 1. Create a copy for export to keep the original data intact
export_df = global_strategy_raw.copy()

# 2. Round all numerical columns to 4 decimal places
# This ensures that Win Rates (0.6543 -> 0.65) and Returns (0.0123 -> 0.01) are consistent
export_df = export_df.round(4)

# 3. Rename columns for the final report
export_df = export_df.rename(columns={
    'SMA_Param': 'SMA',
    'BB_Param': 'BB',
    'Total_Trades': 'Trades'
})

# 4. Export to CSV string
# float_format="%.4f" is a safety measure to ensure trailing zeros are kept (e.g., 0.50)
csv_output = export_df.to_csv(index=False, float_format="%.4f")

print("--- COPY AND PASTE THIS TO GEMINI ---")
print(csv_output)
# Out:
# --- COPY AND PASTE THIS TO GEMINI ---
# SMA,BB,Trades,Win_Rate_3D,Avg_3D_Ret,Win_Rate_5D,Avg_5D_Ret,Win_Rate_10D,Avg_10D_Ret
# 12,10,48,0.4583,0.0005,0.6042,0.0183,0.6667,0.0123
# 14,10,67,0.5373,0.0135,0.5522,0.0147,0.6567,0.0303
# 13,10,68,0.5000,0.0085,0.6029,0.0147,0.6471,0.0187
# 11,10,40,0.5500,0.0133,0.6000,0.0186,0.6250,-0.0060
# 15,10,73,0.4110,-0.0031,0.4795,-0.0004,0.5479,0.0229
# 16,10,75,0.3733,-0.0069,0.4400,-0.0087,0.4533,0.0113
# 11,30,517,0.4526,-0.0096,0.4275,-0.0162,0.4371,-0.0182
# 4,20,968,0.4587,-0.0054,0.4349,-0.0120,0.3750,-0.0248
# 19,20,56,0.4464,-0.0105,0.4821,-0.0211,0.3750,-0.0252
# 4,10,853,0.4420,-0.0051,0.4349,-0.0119,0.3728,-0.0237
# 7,10,413,0.4116,-0.0105,0.3850,-0.0219,0.3680,-0.0232
# 6,20,731,0.4213,-0.0106,0.3995,-0.0198,0.3666,-0.0293
# 5,20,845,0.4260,-0.0095,0.3988,-0.0167,0.3633,-0.0291
# 5,10,683,0.4012,-0.0090,0.3939,-0.0162,0.3558,-0.0281
# 6,10,532,0.3966,-0.0114,0.3872,-0.0211,0.3496,-0.0308

# %%
# 1. Aggregate Advanced Risk Metrics from Raw Data
# We focus on the 10-Day window as it showed the highest potential for spreads
stress_test = master_trade_log.groupby(['SMA_Param', 'BB_Param'])['Ret_10D'].agg([
    ('Trades', 'count'),
    ('Avg_Ret', 'mean'),
    ('Median_Ret', 'median'),
    ('Std_Dev', 'std'),
    ('Win_Rate', lambda x: (x > 0).mean())
]).reset_index()

# 2. Calculate Expectancy Score (Assuming 1:1 Risk/Reward Ratio)
# Formula: (WinRate * 1) - (LossRate * 1)
# A score of 0.10 means you expect to make $0.10 for every $1.00 risked over time.
stress_test['Expectancy_Score'] = (stress_test['Win_Rate'] * 2) - 1

# 3. Sort by Expectancy Score
stress_test = stress_test.sort_values('Expectancy_Score', ascending=False)

print("--- STRATEGY EXPECTANCY & STRESS TEST (10-Day Window) ---")
print("Focus: Finding the most 'reliable' parameters, not just the 'luckiest'.")

display(stress_test.head(10).style.format({
    'Avg_Ret': '{:.2%}',
    'Median_Ret': '{:.2%}',
    'Std_Dev': '{:.2%}',
    'Win_Rate': '{:.1%}',
    'Expectancy_Score': '{:.3f}'
}).background_gradient(subset=['Expectancy_Score'], cmap='Greens'))
# Out:
# --- STRATEGY EXPECTANCY & STRESS TEST (10-Day Window) ---
# Focus: Finding the most 'reliable' parameters, not just the 'luckiest'.
# <style type="text/css">
# #T_5db90_row0_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5db90_row1_col7 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_5db90_row2_col7 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_5db90_row3_col7 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_5db90_row4_col7 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_5db90_row5_col7 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_5db90_row6_col7 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_5db90_row7_col7 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_5db90_row8_col7 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_5db90_row9_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_5db90" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5db90_level0_col0" class="col_heading level0 col0" >SMA_Param</th>
#       <th id="T_5db90_level0_col1" class="col_heading level0 col1" >BB_Param</th>
#       <th id="T_5db90_level0_col2" class="col_heading level0 col2" >Trades</th>
#       <th id="T_5db90_level0_col3" class="col_heading level0 col3" >Avg_Ret</th>
#       <th id="T_5db90_level0_col4" class="col_heading level0 col4" >Median_Ret</th>
#       <th id="T_5db90_level0_col5" class="col_heading level0 col5" >Std_Dev</th>
#       <th id="T_5db90_level0_col6" class="col_heading level0 col6" >Win_Rate</th>
#       <th id="T_5db90_level0_col7" class="col_heading level0 col7" >Expectancy_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5db90_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_5db90_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_5db90_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_5db90_row0_col2" class="data row0 col2" >47</td>
#       <td id="T_5db90_row0_col3" class="data row0 col3" >1.23%</td>
#       <td id="T_5db90_row0_col4" class="data row0 col4" >1.45%</td>
#       <td id="T_5db90_row0_col5" class="data row0 col5" >11.17%</td>
#       <td id="T_5db90_row0_col6" class="data row0 col6" >66.7%</td>
#       <td id="T_5db90_row0_col7" class="data row0 col7" >0.333</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row1" class="row_heading level0 row1" >32</th>
#       <td id="T_5db90_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_5db90_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_5db90_row1_col2" class="data row1 col2" >67</td>
#       <td id="T_5db90_row1_col3" class="data row1 col3" >3.03%</td>
#       <td id="T_5db90_row1_col4" class="data row1 col4" >1.16%</td>
#       <td id="T_5db90_row1_col5" class="data row1 col5" >10.87%</td>
#       <td id="T_5db90_row1_col6" class="data row1 col6" >65.7%</td>
#       <td id="T_5db90_row1_col7" class="data row1 col7" >0.313</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row2" class="row_heading level0 row2" >29</th>
#       <td id="T_5db90_row2_col0" class="data row2 col0" >13</td>
#       <td id="T_5db90_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_5db90_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_5db90_row2_col3" class="data row2 col3" >1.87%</td>
#       <td id="T_5db90_row2_col4" class="data row2 col4" >1.45%</td>
#       <td id="T_5db90_row2_col5" class="data row2 col5" >11.93%</td>
#       <td id="T_5db90_row2_col6" class="data row2 col6" >64.7%</td>
#       <td id="T_5db90_row2_col7" class="data row2 col7" >0.294</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_5db90_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_5db90_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_5db90_row3_col2" class="data row3 col2" >39</td>
#       <td id="T_5db90_row3_col3" class="data row3 col3" >-0.60%</td>
#       <td id="T_5db90_row3_col4" class="data row3 col4" >1.50%</td>
#       <td id="T_5db90_row3_col5" class="data row3 col5" >9.19%</td>
#       <td id="T_5db90_row3_col6" class="data row3 col6" >62.5%</td>
#       <td id="T_5db90_row3_col7" class="data row3 col7" >0.250</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row4" class="row_heading level0 row4" >35</th>
#       <td id="T_5db90_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_5db90_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_5db90_row4_col2" class="data row4 col2" >72</td>
#       <td id="T_5db90_row4_col3" class="data row4 col3" >2.29%</td>
#       <td id="T_5db90_row4_col4" class="data row4 col4" >0.64%</td>
#       <td id="T_5db90_row4_col5" class="data row4 col5" >10.73%</td>
#       <td id="T_5db90_row4_col6" class="data row4 col6" >54.8%</td>
#       <td id="T_5db90_row4_col7" class="data row4 col7" >0.096</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row5" class="row_heading level0 row5" >38</th>
#       <td id="T_5db90_row5_col0" class="data row5 col0" >16</td>
#       <td id="T_5db90_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_5db90_row5_col2" class="data row5 col2" >74</td>
#       <td id="T_5db90_row5_col3" class="data row5 col3" >1.13%</td>
#       <td id="T_5db90_row5_col4" class="data row5 col4" >-0.65%</td>
#       <td id="T_5db90_row5_col5" class="data row5 col5" >11.65%</td>
#       <td id="T_5db90_row5_col6" class="data row5 col6" >45.3%</td>
#       <td id="T_5db90_row5_col7" class="data row5 col7" >-0.093</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row6" class="row_heading level0 row6" >25</th>
#       <td id="T_5db90_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_5db90_row6_col1" class="data row6 col1" >30</td>
#       <td id="T_5db90_row6_col2" class="data row6 col2" >496</td>
#       <td id="T_5db90_row6_col3" class="data row6 col3" >-1.82%</td>
#       <td id="T_5db90_row6_col4" class="data row6 col4" >-0.87%</td>
#       <td id="T_5db90_row6_col5" class="data row6 col5" >11.36%</td>
#       <td id="T_5db90_row6_col6" class="data row6 col6" >43.7%</td>
#       <td id="T_5db90_row6_col7" class="data row6 col7" >-0.126</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_5db90_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_5db90_row7_col1" class="data row7 col1" >30</td>
#       <td id="T_5db90_row7_col2" class="data row7 col2" >468</td>
#       <td id="T_5db90_row7_col3" class="data row7 col3" >-1.56%</td>
#       <td id="T_5db90_row7_col4" class="data row7 col4" >-0.92%</td>
#       <td id="T_5db90_row7_col5" class="data row7 col5" >10.88%</td>
#       <td id="T_5db90_row7_col6" class="data row7 col6" >43.6%</td>
#       <td id="T_5db90_row7_col7" class="data row7 col7" >-0.127</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row8" class="row_heading level0 row8" >34</th>
#       <td id="T_5db90_row8_col0" class="data row8 col0" >14</td>
#       <td id="T_5db90_row8_col1" class="data row8 col1" >30</td>
#       <td id="T_5db90_row8_col2" class="data row8 col2" >415</td>
#       <td id="T_5db90_row8_col3" class="data row8 col3" >-1.67%</td>
#       <td id="T_5db90_row8_col4" class="data row8 col4" >-0.86%</td>
#       <td id="T_5db90_row8_col5" class="data row8 col5" >10.35%</td>
#       <td id="T_5db90_row8_col6" class="data row8 col6" >43.5%</td>
#       <td id="T_5db90_row8_col7" class="data row8 col7" >-0.130</td>
#     </tr>
#     <tr>
#       <th id="T_5db90_level0_row9" class="row_heading level0 row9" >31</th>
#       <td id="T_5db90_row9_col0" class="data row9 col0" >13</td>
#       <td id="T_5db90_row9_col1" class="data row9 col1" >30</td>
#       <td id="T_5db90_row9_col2" class="data row9 col2" >440</td>
#       <td id="T_5db90_row9_col3" class="data row9 col3" >-1.93%</td>
#       <td id="T_5db90_row9_col4" class="data row9 col4" >-1.02%</td>
#       <td id="T_5db90_row9_col5" class="data row9 col5" >10.75%</td>
#       <td id="T_5db90_row9_col6" class="data row9 col6" >42.8%</td>
#       <td id="T_5db90_row9_col7" class="data row9 col7" >-0.145</td>
#     </tr>
#   </tbody>
# </table>
